# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import KFold
from lightgbm.sklearn import LGBMRegressor
from xgboost.sklearn import XGBRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
import time
from sklearn.model_selection import GridSearchCV
import datetime
from catboost import CatBoostRegressor
from sklearn.model_selection import cross_val_score
import pickle

# %%
# sample的

# %%
df1 = pd.read_csv('./data/sample_data.gz')

# %%
test = df1[df1['price'].isnull()]
X_train = df1[df1['price'].notnull()].drop(['price','regDate','creatDate','SaleID','regionCode'],axis=1)
Y_train = df1[df1['price'].notnull()]['price']
X_test = df1[df1['price'].isnull()].drop(['price','regDate','creatDate','SaleID','regionCode'],axis=1)
print("test information:")
X_test.info()
print("X_train information:")
X_train.info()
# Out:
# test information:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50000 entries, 150000 to 199999
# Columns: 139 entries, model to new14*year
# dtypes: float64(104), int64(35)
# memory usage: 53.4 MB
# X_train information:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150000 entries, 0 to 149999
# Columns: 139 entries, model to new14*year
# dtypes: float64(104), int64(35)
# memory usage: 160.2 MB

# %%
X_train.columns
# Out:
# Index(['model', 'brand', 'bodyType', 'fuelType', 'gearbox', 'power',
#        'kilometer', 'notRepairedDamage', 'v_0', 'v_1',
#        ...
#        'new5*year', 'new6*year', 'new7*year', 'new8*year', 'new9*year',
#        'new10*year', 'new11*year', 'new12*year', 'new13*year', 'new14*year'],
#       dtype='object', length=139)

# %%
# light GBM grid search

param = {}
param['gpu_id'] = 0
param['tree_method'] = 'gpu_hist'
lgb = LGBMRegressor(
    n_estimators=1000,
    
    boosting_type= 'gbdt',
    objective = 'regression_l1',
    num_leaves=31,
    min_child_samples = 20,
    feature_fraction = 0.8,
    bagging_freq = 1,
    bagging_fraction = 0.8,
    lambda_l2 = 2,
    random_state=2020,
    metric='mae',
    device = 'gpu'
)

param_grid_gb = {
        'depth': [6, 7, 8],
        'learning_rate': [0.1,0.3]
    }
gs_lgb = GridSearchCV(lgb, param_grid_gb)


skf = KFold(n_splits=5)

params_list = []

lgb_mae = 0
sub_lgb = 0
#交叉验证
for i, (trn_idx, val_idx) in enumerate(skf.split(X_train, Y_train)):
    print('--------------------- {} fold ---------------------'.format(i+1))
    print(datetime.datetime.now())
    trn_x, trn_y = X_train.iloc[trn_idx].reset_index(drop=True), Y_train[trn_idx]
    val_x, val_y = X_train.iloc[val_idx].reset_index(drop=True), Y_train[val_idx]
    # fit函数参数：eval_set=[(x_test,y_test)]  评估数据集,list类型,eval_set用来作为早期停止的验证集，一般我们放x_test和y_test
    # fit函数参数：eval_metric="mlogloss"      评估标准(多分类问题，使用mlogloss作为损失函数)
    # fit函数参数：early_stopping_rounds= 10   如果模型的loss十次内没有减小，则提前结束模型训练
    # fit函数参数：verbose = True              True显示，False不显示
    #import pdb;pdb.set_trace()
    gs_lgb.fit(
        trn_x, trn_y,
        eval_set=[(val_x, val_y)], 
                eval_metric='mae',
        early_stopping_rounds=300,
        #verbose_eval=300
        verbose=False
    )
    
    params_list.append(gs_lgb.best_params_)

    sub_lgb += np.expm1(gs_lgb.predict(X_test)) / skf.n_splits
    val_lgb = gs_lgb.predict(val_x)
    print('val mae:', mean_absolute_error(np.expm1(val_y), np.expm1(val_lgb)))
    lgb_mae += mean_absolute_error(np.expm1(val_y), np.expm1(val_lgb))/skf.n_splits
    print(datetime.datetime.now())
    print(params_list)
print('MAE of val with lgb:', lgb_mae)
# Out:
# --------------------- 1 fold ---------------------
# 2020-08-27 04:22:37.455078
# val mae: 494.53909542936333
# 2020-08-27 05:01:16.009369
# [{'depth': 6, 'learning_rate': 0.1}]
# --------------------- 2 fold ---------------------
# 2020-08-27 05:01:16.013357
# val mae: 496.5083744920362
# 2020-08-27 05:39:55.225751
# [{'depth': 6, 'learning_rate': 0.1}, {'depth': 6, 'learning_rate': 0.1}]
# --------------------- 3 fold ---------------------
# 2020-08-27 05:39:55.230736
# val mae: 503.20864604908263
# 2020-08-27 06:18:49.020245
# [{'depth': 6, 'learning_rate': 0.1}, {'depth': 6, 'learning_rate': 0.1}, {'depth': 6, 'learning_rate': 0.1}]
# --------------------- 4 fold ---------------------
# 2020-08-27 06:18:49.025233
# val mae: 493.8136790087865
# 2020-08-27 06:57:52.049557
# [{'depth': 6, 'learning_rate': 0.1}, {'depth': 6, 'learning_rate': 0.1}, {'depth': 6, 'learning_rate': 0.1}, {'depth': 6, 'learning_rate': 0.1}]
# --------------------- 5 fold ---------------------
# 2020-08-27 06:57:52.053546
# val mae: 494.17437452166183
# 2020-08-27 09:33:55.328110
# [{'depth': 6, 'learning_rate': 0.1}, {'depth': 6, 'learning_rate': 0.1}, {'depth': 6, 'learning_rate': 0.1}, {'depth': 6, 'learning_rate': 0.1}, {'depth': 6, 'learning_rate': 0.1}]
# MAE of val with lgb: 496.44883390018606

# %%
# Catboost grid search
skf = KFold(n_splits=5)
cat = CatBoostRegressor(loss_function='RMSE',task_type='GPU', 
#                         cat_features = ['brand','model','kilometer','fuelType','bodyType'],
                       early_stopping_rounds=300, n_estimators=3000
                       )
param_grid_cat = {
        'depth': [6, 7, 8]
    }

param_list_cat = []

gs_cat = GridSearchCV(cat, param_grid_cat)
cat_mae = 0
sub_cat = 0
for i, (trn_idx, val_idx) in enumerate(skf.split(X_train, Y_train)):
    print('--------------------- {} fold ---------------------'.format(i+1))
    print(datetime.datetime.now())
    trn_x, trn_y = X_train.iloc[trn_idx].reset_index(drop=True), Y_train[trn_idx]
    val_x, val_y = X_train.iloc[val_idx].reset_index(drop=True), Y_train[val_idx]
    # fit函数参数：eval_set=[(x_test,y_test)]  评估数据集,list类型,eval_set用来作为早期停止的验证集，一般我们放x_test和y_test
    # fit函数参数：eval_metric="mlogloss"      评估标准(多分类问题，使用mlogloss作为损失函数)
    # fit函数参数：early_stopping_rounds= 10   如果模型的loss十次内没有减小，则提前结束模型训练
    # fit函数参数：verbose = True              True显示，False不显示
    gs_cat.fit(
        trn_x, trn_y,
        verbose=False
    )
    sub_cat += np.expm1(gs_cat.predict(X_test)) / skf.n_splits
    val_cat= gs_cat.predict(val_x)
    print('val mae:', mean_absolute_error(np.expm1(val_y), np.expm1(val_cat)))
    cat_mae += mean_absolute_error(np.expm1(val_y), np.expm1(val_cat))/skf.n_splits
    param_list_cat.append(gs_cat.best_params_)
    print(param_list_cat)
    print(datetime.datetime.now())

print('MAE of val with xgb:', cat_mae)
# Out:
# --------------------- 1 fold ---------------------
# 2020-08-27 09:33:55.394485
# val mae: 639.0691784241376
# [{'depth': 8}]
# 2020-08-27 09:53:08.993182
# --------------------- 2 fold ---------------------
# 2020-08-27 09:53:08.995177
# val mae: 644.4911278385617
# [{'depth': 8}, {'depth': 8}]
# 2020-08-27 10:12:16.760236
# --------------------- 3 fold ---------------------
# 2020-08-27 10:12:16.762230
# val mae: 645.396266936107
# [{'depth': 8}, {'depth': 8}, {'depth': 8}]
# 2020-08-27 10:31:21.417263
# --------------------- 4 fold ---------------------
# 2020-08-27 10:31:21.420255
# val mae: 661.5011848952386
# [{'depth': 8}, {'depth': 8}, {'depth': 8}, {'depth': 8}]
# 2020-08-27 10:50:22.189596
# --------------------- 5 fold ---------------------
# 2020-08-27 10:50:22.192589
# val mae: 657.3969323950894
# [{'depth': 8}, {'depth': 8}, {'depth': 8}, {'depth': 8}, {'depth': 8}]
# 2020-08-27 11:09:24.100630
# MAE of val with xgb: 649.5709380978269

# %%
save_file1 = open('sample_cat.pkl', 'wb')
# 将列表写入文件
pickle.dump(cat_mae, save_file1)
pickle.dump(sub_cat, save_file1)
save_file1.close()

# %%
save_file = open('sample_lgb.pkl', 'wb')
# 将列表写入文件
pickle.dump(lgb_mae, save_file)
pickle.dump(sub_lgb, save_file)
save_file.close()

# %%
sub_Weighted = (1-lgb_mae/(cat_mae+lgb_mae))*sub_lgb+(1-cat_mae/(cat_mae+lgb_mae))*sub_cat

# %%
res = {}
res['SaleID'] = test['SaleID']
res['price'] = sub_Weighted

res_df = pd.DataFrame(res)

res_df.to_csv('./data/cat_lgb_gs_sample.csv', index=None)

# %%
# 自己的

# %%
df2 = pd.read_csv('./data/merged_data_for_tree.gz')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199037 entries, 0 to 199036
# Columns: 189 entries, SaleID to poly_feat_v_0 v_3 v_8 v_12
# dtypes: float64(116), int64(73)
# memory usage: 287.0 MB

# %%
X_train1 = df2[df2['price'].notnull()].drop(['price','regDate','creatDate','SaleID','regionCode','train', 'name', 'seller', 'offerType'],axis=1)
Y_train1 = df2[df2['price'].notnull()]['price']
X_test1 = df2[df2['price'].isnull()].drop(['price','regDate','creatDate','SaleID','regionCode','train', 'name', 'seller', 'offerType'],axis=1)
print("test information:")
X_test1.info()
print("X_train information:")
X_train1.info()
# Out:
# test information:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50000 entries, 149037 to 199036
# Columns: 180 entries, model to poly_feat_v_0 v_3 v_8 v_12
# dtypes: float64(115), int64(65)
# memory usage: 69.0 MB
# X_train information:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 149037 entries, 0 to 149036
# Columns: 180 entries, model to poly_feat_v_0 v_3 v_8 v_12
# dtypes: float64(115), int64(65)
# memory usage: 205.8 MB

# %%
X_train1.columns
# Out:
# Index(['model', 'brand', 'power', 'kilometer', 'v_0', 'v_1', 'v_2', 'v_3',
#        'v_4', 'v_5',
#        ...
#        'poly_feat_v_0 v_8', 'poly_feat_v_0 v_12', 'poly_feat_v_3 v_8',
#        'poly_feat_v_3 v_12', 'poly_feat_v_8 v_12', 'poly_feat_v_0 v_3 v_8',
#        'poly_feat_v_0 v_3 v_12', 'poly_feat_v_0 v_8 v_12',
#        'poly_feat_v_3 v_8 v_12', 'poly_feat_v_0 v_3 v_8 v_12'],
#       dtype='object', length=180)

# %%
# light GBM grid search

param = {}
param['gpu_id'] = 0
param['tree_method'] = 'gpu_hist'
lgb = LGBMRegressor(
    n_estimators=1000,

    boosting_type= 'gbdt',
    objective = 'regression_l1',
    num_leaves=31,
    min_child_samples = 20,
    feature_fraction = 0.8,
    bagging_freq = 1,
    bagging_fraction = 0.8,
    lambda_l2 = 2,
    random_state=2020,
    metric='mae',
    device = 'gpu'
)

param_grid_gb = {
        'depth': [6, 7, 8],
    'learning_rate': [0.1,0.3]
    }
gs_lgb1 = GridSearchCV(lgb, param_grid_gb)


skf = KFold(n_splits=5)

params_list1 = []

lgb_mae1 = 0
sub_lgb1 = 0
#交叉验证
for i, (trn_idx, val_idx) in enumerate(skf.split(X_train1, Y_train1)):
    print('--------------------- {} fold ---------------------'.format(i+1))
    print(datetime.datetime.now())
    trn_x, trn_y = X_train1.iloc[trn_idx].reset_index(drop=True), Y_train1[trn_idx]
    val_x, val_y = X_train1.iloc[val_idx].reset_index(drop=True), Y_train1[val_idx]
    # fit函数参数：eval_set=[(x_test,y_test)]  评估数据集,list类型,eval_set用来作为早期停止的验证集，一般我们放x_test和y_test
    # fit函数参数：eval_metric="mlogloss"      评估标准(多分类问题，使用mlogloss作为损失函数)
    # fit函数参数：early_stopping_rounds= 10   如果模型的loss十次内没有减小，则提前结束模型训练
    # fit函数参数：verbose = True              True显示，False不显示
    #import pdb;pdb.set_trace()
    gs_lgb1.fit(
        trn_x, trn_y,
        eval_set=[(val_x, val_y)], 
                eval_metric='mae',
        early_stopping_rounds=300,
        #verbose_eval=300
        verbose=False
    )
    
    params_list1.append(gs_lgb1.best_params_)

    sub_lgb1 += np.expm1(gs_lgb1.predict(X_test1)) / skf.n_splits
    val_lgb1 = gs_lgb1.predict(val_x)
    print('val mae:', mean_absolute_error(np.expm1(val_y), np.expm1(val_lgb1)))
    lgb_mae1 += mean_absolute_error(np.expm1(val_y), np.expm1(val_lgb1))/skf.n_splits
    print(datetime.datetime.now())
    print(params_list1)
print('MAE of val with lgb:', lgb_mae1)
# Out:
# --------------------- 1 fold ---------------------
# 2020-08-27 11:09:34.680551
# val mae: 492.81884632727883
# 2020-08-27 11:51:25.789853
# [{'depth': 6, 'learning_rate': 0.1}]
# --------------------- 2 fold ---------------------
# 2020-08-27 11:51:25.795838
# val mae: 496.25993988474005
# 2020-08-27 12:34:03.187906
# [{'depth': 6, 'learning_rate': 0.1}, {'depth': 6, 'learning_rate': 0.1}]
# --------------------- 3 fold ---------------------
# 2020-08-27 12:34:03.195886
# val mae: 506.60961970315265
# 2020-08-27 13:19:48.479596
# [{'depth': 6, 'learning_rate': 0.1}, {'depth': 6, 'learning_rate': 0.1}, {'depth': 6, 'learning_rate': 0.1}]
# --------------------- 4 fold ---------------------
# 2020-08-27 13:19:48.485581
# val mae: 489.45286118136863
# 2020-08-27 14:06:20.217588
# [{'depth': 6, 'learning_rate': 0.1}, {'depth': 6, 'learning_rate': 0.1}, {'depth': 6, 'learning_rate': 0.1}, {'depth': 6, 'learning_rate': 0.1}]
# --------------------- 5 fold ---------------------
# 2020-08-27 14:06:20.226563
# val mae: 504.70372258919423
# 2020-08-27 14:51:55.164712
# [{'depth': 6, 'learning_rate': 0.1}, {'depth': 6, 'learning_rate': 0.1}, {'depth': 6, 'learning_rate': 0.1}, {'depth': 6, 'learning_rate': 0.1}, {'depth': 6, 'learning_rate': 0.1}]
# MAE of val with lgb: 497.9689979371469

# %%
# Catboost grid search
skf = KFold(n_splits=5)
cat1 = CatBoostRegressor(loss_function='RMSE',task_type='GPU', 
#                         cat_features = ['brand','model','kilometer','fuelType','bodyType'],
                       early_stopping_rounds=300,n_estimators=3000
                       )
param_grid_cat1 = {
        'depth': [6, 7, 8]
    }

param_list_cat1 = []

gs_cat1 = GridSearchCV(cat1, param_grid_cat1)
cat_mae1 = 0
sub_cat1 = 0
for i, (trn_idx, val_idx) in enumerate(skf.split(X_train1, Y_train1)):
    print('--------------------- {} fold ---------------------'.format(i+1))
    print(datetime.datetime.now())
    trn_x, trn_y = X_train1.iloc[trn_idx].reset_index(drop=True), Y_train1[trn_idx]
    val_x, val_y = X_train1.iloc[val_idx].reset_index(drop=True), Y_train1[val_idx]
    # fit函数参数：eval_set=[(x_test,y_test)]  评估数据集,list类型,eval_set用来作为早期停止的验证集，一般我们放x_test和y_test
    # fit函数参数：eval_metric="mlogloss"      评估标准(多分类问题，使用mlogloss作为损失函数)
    # fit函数参数：early_stopping_rounds= 10   如果模型的loss十次内没有减小，则提前结束模型训练
    # fit函数参数：verbose = True              True显示，False不显示
    gs_cat1.fit(
        trn_x, trn_y,
        verbose=False
    )
    sub_cat1 += np.expm1(gs_cat1.predict(X_test1)) / skf.n_splits
    val_cat1 = gs_cat1.predict(val_x)
    print('val mae:', mean_absolute_error(np.expm1(val_y), np.expm1(val_cat1)))
    cat_mae1 += mean_absolute_error(np.expm1(val_y), np.expm1(val_cat1))/skf.n_splits
    param_list_cat1.append(gs_cat1.best_params_)
    print(param_list_cat1)
    print(datetime.datetime.now())

print('MAE of val with xgb:', cat_mae1)
# Out:
# --------------------- 1 fold ---------------------
# 2020-08-27 14:51:55.241506
# val mae: 683.59799850938
# [{'depth': 8}]
# 2020-08-27 15:10:47.235782
# --------------------- 2 fold ---------------------
# 2020-08-27 15:10:47.239772
# val mae: 620.5030622023072
# [{'depth': 8}, {'depth': 8}]
# 2020-08-27 15:29:08.575036
# --------------------- 3 fold ---------------------
# 2020-08-27 15:29:08.579025
# val mae: 665.7393007205118
# [{'depth': 8}, {'depth': 8}, {'depth': 8}]
# 2020-08-27 15:46:52.285462
# --------------------- 4 fold ---------------------
# 2020-08-27 15:46:52.289451
# val mae: 629.6107849146656
# [{'depth': 8}, {'depth': 8}, {'depth': 8}, {'depth': 8}]
# 2020-08-27 16:05:08.630275
# --------------------- 5 fold ---------------------
# 2020-08-27 16:05:08.635261
# val mae: 630.860063381233
# [{'depth': 8}, {'depth': 8}, {'depth': 8}, {'depth': 8}, {'depth': 8}]
# 2020-08-27 16:23:35.319711
# MAE of val with xgb: 646.0622419456196

# %%
sub_Weighted1 = (1-lgb_mae1/(cat_mae1+lgb_mae1))*sub_lgb1+(1-cat_mae1/(cat_mae1+lgb_mae1))*sub_cat1

# %%
res = {}
res['SaleID'] = test['SaleID']
res['price'] = sub_Weighted1

res_df = pd.DataFrame(res)

res_df.to_csv('./data/cat_lgb_gs_1.csv', index=None)

# %%
save_file2 = open('my_cat.pkl', 'wb')
# 将列表写入文件
pickle.dump(cat_mae1, save_file2)
pickle.dump(sub_cat1, save_file2)
save_file2.close()

# %%
save_file3 = open('my_lgb.pkl', 'wb')
# 将列表写入文件
pickle.dump(lgb_mae1, save_file3)
pickle.dump(sub_lgb1, save_file3)
save_file3.close()

# %%
# stacking
# from sklearn.ensemble import StackingRegressor
from sklearn.ensemble import BaggingRegressor
from mlxtend.regressor import StackingRegressor
# from lightgbm.sklearn import LGBMRegressor

# %%
LGBMRegressor.__base__
# Out:
# lightgbm.sklearn.LGBMModel

# %%
lgb_instance = LGBMRegressor(
    n_estimators=10000,
    boosting_type= 'gbdt',
    objective = 'regression_l1',
    num_leaves=31,
    min_child_samples = 20,
    feature_fraction = 0.8,
    bagging_freq = 1,
    bagging_fraction = 0.8,
    lambda_l2 = 2,
    random_state=2020,
    metric='mae',
    device = 'gpu',
    learning_rate = 0.02,
    verbose=4
)

cat_reg = CatBoostRegressor(loss_function='RMSE',task_type='GPU', verbose=False)

estimators = [lgb_instance, cat_reg]

reg = StackingRegressor(
     regressors=estimators, 
    meta_regressor=BaggingRegressor(n_estimators=100,random_state=42)
     )

# %%
reg.fit(X_train, Y_train)
# Out:
# Warning: less than 75% gpu memory available for training. Free: 1520.690234 Total: 2048
# StackingRegressor(meta_regressor=BaggingRegressor(n_estimators=100,
#                                                   random_state=42),
#                   regressors=[LGBMRegressor(bagging_fraction=0.8,
#                                             bagging_freq=1, device='gpu',
#                                             feature_fraction=0.8, lambda_l2=2,
#                                             learning_rate=0.02, metric='mae',
#                                             n_estimators=10000,
#                                             objective='regression_l1',
#                                             random_state=2020, verbose=4),
#                               <catboost.core.CatBoostRegressor object at 0x000001E3FF968808>])

# %%
y_pre = reg.predict(X_test)

# %%
y_pre = np.expm1(y_pre)

# %%
res = {}
res['SaleID'] = test['SaleID']
res['price'] = y_pre

res_df = pd.DataFrame(res)

res_df.to_csv('./data/stacking_ensemble.csv', index=None)

# %%
cat_features=['brand','model','kilometer','fuelType','bodyType']

X_train[cat_features] = X_train[cat_features].astype(int)
X_train['brand'].head()
# Out:
# 0     6
# 1     1
# 2    15
# 3    10
# 4     5
# Name: brand, dtype: int32

# %%
cat_reg= CatBoostRegressor(loss_function='RMSE',task_type='GPU', verbose=True, cat_features=cat_features)
cat_reg.fit(X_train, Y_train)
# Out:
# Learning rate set to 0.084261
# 0:	learn: 1.2142988	total: 76.8ms	remaining: 1m 16s
# 1:	learn: 1.2078055	total: 138ms	remaining: 1m 9s
# 2:	learn: 1.1987691	total: 229ms	remaining: 1m 16s
# 3:	learn: 1.1915208	total: 283ms	remaining: 1m 10s
# 4:	learn: 1.1857408	total: 382ms	remaining: 1m 16s
# 5:	learn: 1.1851781	total: 473ms	remaining: 1m 18s
# 6:	learn: 1.1739317	total: 541ms	remaining: 1m 16s
# 7:	learn: 1.1699936	total: 636ms	remaining: 1m 18s
# 8:	learn: 1.1636908	total: 742ms	remaining: 1m 21s
# 9:	learn: 1.1627082	total: 831ms	remaining: 1m 22s
# 10:	learn: 1.1471680	total: 922ms	remaining: 1m 22s
# 11:	learn: 1.1280723	total: 1.01s	remaining: 1m 23s
# 12:	learn: 1.1264812	total: 1.11s	remaining: 1m 24s
# 13:	learn: 1.1083924	total: 1.21s	remaining: 1m 25s
# 14:	learn: 1.1028913	total: 1.31s	remaining: 1m 26s
# 15:	learn: 1.0918144	total: 1.38s	remaining: 1m 24s
# 16:	learn: 1.0904352	total: 1.47s	remaining: 1m 25s
# 17:	learn: 1.0803327	total: 1.54s	remaining: 1m 24s
# 18:	learn: 1.0667508	total: 1.6s	remaining: 1m 22s
# 19:	learn: 1.0612974	total: 1.69s	remaining: 1m 22s
# 20:	learn: 1.0555148	total: 1.76s	remaining: 1m 22s
# 21:	learn: 1.0532305	total: 1.85s	remaining: 1m 22s
# 22:	learn: 1.0486549	total: 1.95s	remaining: 1m 22s
# 23:	learn: 1.0462936	total: 2.03s	remaining: 1m 22s
# 24:	learn: 1.0411354	total: 2.12s	remaining: 1m 22s
# 25:	learn: 1.0303341	total: 2.19s	remaining: 1m 22s
# 26:	learn: 1.0184444	total: 2.27s	remaining: 1m 21s
# 27:	learn: 1.0142515	total: 2.37s	remaining: 1m 22s
# 28:	learn: 1.0055731	total: 2.45s	remaining: 1m 22s
# 29:	learn: 1.0048194	total: 2.52s	remaining: 1m 21s
# 30:	learn: 1.0035380	total: 2.61s	remaining: 1m 21s
# 31:	learn: 1.0017791	total: 2.71s	remaining: 1m 21s
# 32:	learn: 0.9867723	total: 2.81s	remaining: 1m 22s
# 33:	learn: 0.9846559	total: 2.9s	remaining: 1m 22s
# 34:	learn: 0.9769161	total: 3.01s	remaining: 1m 22s
# 35:	learn: 0.9685152	total: 3.07s	remaining: 1m 22s
# 36:	learn: 0.9605418	total: 3.18s	remaining: 1m 22s
# 37:	learn: 0.9530454	total: 3.28s	remaining: 1m 22s
# 38:	learn: 0.9180841	total: 3.37s	remaining: 1m 23s
# 39:	learn: 0.9156733	total: 3.46s	remaining: 1m 23s
# 40:	learn: 0.9037553	total: 3.54s	remaining: 1m 22s
# 41:	learn: 0.8904141	total: 3.61s	remaining: 1m 22s
# 42:	learn: 0.8880487	total: 3.71s	remaining: 1m 22s
# 43:	learn: 0.8795217	total: 3.81s	remaining: 1m 22s
# 44:	learn: 0.8666792	total: 3.88s	remaining: 1m 22s
# 45:	learn: 0.8576378	total: 3.97s	remaining: 1m 22s
# 46:	learn: 0.8563941	total: 4.05s	remaining: 1m 22s
# 47:	learn: 0.8558239	total: 4.12s	remaining: 1m 21s
# 48:	learn: 0.8445452	total: 4.21s	remaining: 1m 21s
# 49:	learn: 0.8339974	total: 4.3s	remaining: 1m 21s
# 50:	learn: 0.8269711	total: 4.39s	remaining: 1m 21s
# 51:	learn: 0.8208777	total: 4.48s	remaining: 1m 21s
# 52:	learn: 0.8181946	total: 4.59s	remaining: 1m 21s
# 53:	learn: 0.8076546	total: 4.68s	remaining: 1m 21s
# 54:	learn: 0.8022430	total: 4.78s	remaining: 1m 22s
# 55:	learn: 0.7991572	total: 4.85s	remaining: 1m 21s
# 56:	learn: 0.7890705	total: 4.94s	remaining: 1m 21s
# 57:	learn: 0.7839693	total: 4.99s	remaining: 1m 21s
# 58:	learn: 0.7810675	total: 5.09s	remaining: 1m 21s
# 59:	learn: 0.7801999	total: 5.15s	remaining: 1m 20s
# 60:	learn: 0.7783236	total: 5.26s	remaining: 1m 20s
# 61:	learn: 0.7718454	total: 5.32s	remaining: 1m 20s
# 62:	learn: 0.7682591	total: 5.41s	remaining: 1m 20s
# 63:	learn: 0.7671747	total: 5.52s	remaining: 1m 20s
# 64:	learn: 0.7656762	total: 5.6s	remaining: 1m 20s
# 65:	learn: 0.7604745	total: 5.7s	remaining: 1m 20s
# 66:	learn: 0.7578064	total: 5.79s	remaining: 1m 20s
# 67:	learn: 0.7550904	total: 5.88s	remaining: 1m 20s
# 68:	learn: 0.7538500	total: 5.96s	remaining: 1m 20s
# 69:	learn: 0.7455735	total: 6.05s	remaining: 1m 20s
# 70:	learn: 0.7363096	total: 6.13s	remaining: 1m 20s
# 71:	learn: 0.7338296	total: 6.21s	remaining: 1m 20s
# 72:	learn: 0.7301304	total: 6.32s	remaining: 1m 20s
# 73:	learn: 0.7207478	total: 6.4s	remaining: 1m 20s
# 74:	learn: 0.7168698	total: 6.51s	remaining: 1m 20s
# 75:	learn: 0.7121544	total: 6.59s	remaining: 1m 20s
# 76:	learn: 0.7036511	total: 6.68s	remaining: 1m 20s
# 77:	learn: 0.6949300	total: 6.78s	remaining: 1m 20s
# 78:	learn: 0.6870875	total: 6.85s	remaining: 1m 19s
# 79:	learn: 0.6794331	total: 6.95s	remaining: 1m 19s
# 80:	learn: 0.6765242	total: 7.05s	remaining: 1m 19s
# 81:	learn: 0.6724382	total: 7.12s	remaining: 1m 19s
# 82:	learn: 0.6645223	total: 7.18s	remaining: 1m 19s
# 83:	learn: 0.6606675	total: 7.24s	remaining: 1m 18s
# 84:	learn: 0.6583387	total: 7.32s	remaining: 1m 18s
# 85:	learn: 0.6519737	total: 7.4s	remaining: 1m 18s
# 86:	learn: 0.6455599	total: 7.48s	remaining: 1m 18s
# 87:	learn: 0.6383773	total: 7.59s	remaining: 1m 18s
# 88:	learn: 0.6363122	total: 7.67s	remaining: 1m 18s
# 89:	learn: 0.6341003	total: 7.73s	remaining: 1m 18s
# 90:	learn: 0.6286086	total: 7.79s	remaining: 1m 17s
# 91:	learn: 0.6217047	total: 7.88s	remaining: 1m 17s
# 92:	learn: 0.6162471	total: 7.99s	remaining: 1m 17s
# 93:	learn: 0.6112202	total: 8.1s	remaining: 1m 18s
# 94:	learn: 0.6086872	total: 8.18s	remaining: 1m 17s
# 95:	learn: 0.6070032	total: 8.27s	remaining: 1m 17s
# 96:	learn: 0.6035588	total: 8.34s	remaining: 1m 17s
# 97:	learn: 0.5972672	total: 8.43s	remaining: 1m 17s
# 98:	learn: 0.5931283	total: 8.53s	remaining: 1m 17s
# 99:	learn: 0.5899973	total: 8.6s	remaining: 1m 17s
# 100:	learn: 0.5890598	total: 8.67s	remaining: 1m 17s
# 101:	learn: 0.5846765	total: 8.76s	remaining: 1m 17s
# 102:	learn: 0.5794084	total: 8.87s	remaining: 1m 17s
# 103:	learn: 0.5785740	total: 8.97s	remaining: 1m 17s
# 104:	learn: 0.5736019	total: 9.06s	remaining: 1m 17s
# 105:	learn: 0.5701455	total: 9.14s	remaining: 1m 17s
# 106:	learn: 0.5675750	total: 9.23s	remaining: 1m 17s
# 107:	learn: 0.5638117	total: 9.3s	remaining: 1m 16s
# 108:	learn: 0.5593487	total: 9.4s	remaining: 1m 16s
# 109:	learn: 0.5557443	total: 9.49s	remaining: 1m 16s
# 110:	learn: 0.5523148	total: 9.59s	remaining: 1m 16s
# 111:	learn: 0.5518062	total: 9.68s	remaining: 1m 16s
# 112:	learn: 0.5504300	total: 9.78s	remaining: 1m 16s
# 113:	learn: 0.5484994	total: 9.86s	remaining: 1m 16s
# 114:	learn: 0.5452286	total: 9.94s	remaining: 1m 16s
# 115:	learn: 0.5394073	total: 10.1s	remaining: 1m 16s
# 116:	learn: 0.5388579	total: 10.2s	remaining: 1m 16s
# 117:	learn: 0.5342735	total: 10.3s	remaining: 1m 16s
# 118:	learn: 0.5314816	total: 10.3s	remaining: 1m 16s
# 119:	learn: 0.5278895	total: 10.4s	remaining: 1m 16s
# 120:	learn: 0.5251238	total: 10.5s	remaining: 1m 16s
# 121:	learn: 0.5236866	total: 10.6s	remaining: 1m 16s
# 122:	learn: 0.5209951	total: 10.7s	remaining: 1m 16s
# 123:	learn: 0.5201526	total: 10.8s	remaining: 1m 16s
# 124:	learn: 0.5168110	total: 10.9s	remaining: 1m 16s
# 125:	learn: 0.5124862	total: 11s	remaining: 1m 16s
# 126:	learn: 0.5110131	total: 11.1s	remaining: 1m 16s
# 127:	learn: 0.5091868	total: 11.2s	remaining: 1m 16s
# 128:	learn: 0.5056600	total: 11.3s	remaining: 1m 16s
# 129:	learn: 0.5029229	total: 11.4s	remaining: 1m 16s
# 130:	learn: 0.5014300	total: 11.5s	remaining: 1m 16s
# 131:	learn: 0.4986087	total: 11.6s	remaining: 1m 16s
# 132:	learn: 0.4966826	total: 11.7s	remaining: 1m 16s
# 133:	learn: 0.4952676	total: 11.8s	remaining: 1m 16s
# 134:	learn: 0.4906485	total: 11.9s	remaining: 1m 16s
# 135:	learn: 0.4895546	total: 12s	remaining: 1m 16s
# 136:	learn: 0.4853409	total: 12.1s	remaining: 1m 16s
# 137:	learn: 0.4831014	total: 12.2s	remaining: 1m 16s
# 138:	learn: 0.4819542	total: 12.3s	remaining: 1m 15s
# 139:	learn: 0.4797700	total: 12.3s	remaining: 1m 15s
# 140:	learn: 0.4763682	total: 12.4s	remaining: 1m 15s
# 141:	learn: 0.4753112	total: 12.5s	remaining: 1m 15s
# 142:	learn: 0.4741507	total: 12.6s	remaining: 1m 15s
# 143:	learn: 0.4727475	total: 12.7s	remaining: 1m 15s
# 144:	learn: 0.4716704	total: 12.8s	remaining: 1m 15s
# 145:	learn: 0.4680346	total: 12.9s	remaining: 1m 15s
# 146:	learn: 0.4670191	total: 13s	remaining: 1m 15s
# 147:	learn: 0.4662017	total: 13.1s	remaining: 1m 15s
# 148:	learn: 0.4645984	total: 13.2s	remaining: 1m 15s
# 149:	learn: 0.4627667	total: 13.3s	remaining: 1m 15s
# 150:	learn: 0.4602407	total: 13.4s	remaining: 1m 15s
# 151:	learn: 0.4585361	total: 13.5s	remaining: 1m 15s
# 152:	learn: 0.4574885	total: 13.6s	remaining: 1m 15s
# 153:	learn: 0.4567112	total: 13.7s	remaining: 1m 15s
# 154:	learn: 0.4544188	total: 13.8s	remaining: 1m 15s
# 155:	learn: 0.4533459	total: 13.9s	remaining: 1m 15s
# 156:	learn: 0.4518273	total: 14s	remaining: 1m 14s
# 157:	learn: 0.4504505	total: 14s	remaining: 1m 14s
# 158:	learn: 0.4494426	total: 14.1s	remaining: 1m 14s
# 159:	learn: 0.4487501	total: 14.2s	remaining: 1m 14s
# 160:	learn: 0.4471183	total: 14.3s	remaining: 1m 14s
# 161:	learn: 0.4451141	total: 14.4s	remaining: 1m 14s
# 162:	learn: 0.4439006	total: 14.5s	remaining: 1m 14s
# 163:	learn: 0.4431630	total: 14.6s	remaining: 1m 14s
# 164:	learn: 0.4425122	total: 14.7s	remaining: 1m 14s
# 165:	learn: 0.4399405	total: 14.7s	remaining: 1m 14s
# 166:	learn: 0.4387798	total: 14.8s	remaining: 1m 14s
# 167:	learn: 0.4368515	total: 14.9s	remaining: 1m 13s
# 168:	learn: 0.4352781	total: 15s	remaining: 1m 13s
# 169:	learn: 0.4348846	total: 15.1s	remaining: 1m 13s
# 170:	learn: 0.4342275	total: 15.2s	remaining: 1m 13s
# 171:	learn: 0.4336907	total: 15.3s	remaining: 1m 13s
# 172:	learn: 0.4333005	total: 15.4s	remaining: 1m 13s
# 173:	learn: 0.4324072	total: 15.5s	remaining: 1m 13s
# 174:	learn: 0.4313273	total: 15.6s	remaining: 1m 13s
# 175:	learn: 0.4305152	total: 15.7s	remaining: 1m 13s
# 176:	learn: 0.4296273	total: 15.8s	remaining: 1m 13s
# 177:	learn: 0.4276875	total: 15.9s	remaining: 1m 13s
# 178:	learn: 0.4256874	total: 16s	remaining: 1m 13s
# 179:	learn: 0.4248615	total: 16.1s	remaining: 1m 13s
# 180:	learn: 0.4242830	total: 16.2s	remaining: 1m 13s
# 181:	learn: 0.4235973	total: 16.2s	remaining: 1m 12s
# 182:	learn: 0.4224215	total: 16.4s	remaining: 1m 13s
# 183:	learn: 0.4203835	total: 16.5s	remaining: 1m 13s
# 184:	learn: 0.4193223	total: 16.6s	remaining: 1m 12s
# 185:	learn: 0.4149323	total: 16.7s	remaining: 1m 12s
# 186:	learn: 0.4133123	total: 16.8s	remaining: 1m 12s
# 187:	learn: 0.4126432	total: 16.9s	remaining: 1m 12s
# 188:	learn: 0.4112388	total: 17s	remaining: 1m 12s
# 189:	learn: 0.4101970	total: 17.1s	remaining: 1m 12s
# 190:	learn: 0.4094770	total: 17.2s	remaining: 1m 12s
# 191:	learn: 0.4085399	total: 17.3s	remaining: 1m 12s
# 192:	learn: 0.4077763	total: 17.4s	remaining: 1m 12s
# 193:	learn: 0.4062848	total: 17.5s	remaining: 1m 12s
# 194:	learn: 0.4053878	total: 17.6s	remaining: 1m 12s
# 195:	learn: 0.4047583	total: 17.7s	remaining: 1m 12s
# 196:	learn: 0.4043137	total: 17.8s	remaining: 1m 12s
# 197:	learn: 0.4034003	total: 17.9s	remaining: 1m 12s
# 198:	learn: 0.4023940	total: 17.9s	remaining: 1m 12s
# 199:	learn: 0.4021153	total: 18s	remaining: 1m 12s
# 200:	learn: 0.4011922	total: 18.1s	remaining: 1m 12s
# 201:	learn: 0.4007996	total: 18.2s	remaining: 1m 11s
# 202:	learn: 0.4000512	total: 18.3s	remaining: 1m 11s
# 203:	learn: 0.3996391	total: 18.4s	remaining: 1m 11s
# 204:	learn: 0.3986491	total: 18.5s	remaining: 1m 11s
# 205:	learn: 0.3983410	total: 18.6s	remaining: 1m 11s
# 206:	learn: 0.3973151	total: 18.7s	remaining: 1m 11s
# 207:	learn: 0.3969651	total: 18.8s	remaining: 1m 11s
# 208:	learn: 0.3967259	total: 18.9s	remaining: 1m 11s
# 209:	learn: 0.3960305	total: 19s	remaining: 1m 11s
# 210:	learn: 0.3956908	total: 19.1s	remaining: 1m 11s
# 211:	learn: 0.3952327	total: 19.1s	remaining: 1m 11s
# 212:	learn: 0.3947473	total: 19.2s	remaining: 1m 11s
# 213:	learn: 0.3939919	total: 19.3s	remaining: 1m 10s
# 214:	learn: 0.3936741	total: 19.4s	remaining: 1m 10s
# 215:	learn: 0.3932593	total: 19.5s	remaining: 1m 10s
# 216:	learn: 0.3926758	total: 19.6s	remaining: 1m 10s
# 217:	learn: 0.3920194	total: 19.7s	remaining: 1m 10s
# 218:	learn: 0.3917243	total: 19.7s	remaining: 1m 10s
# 219:	learn: 0.3914295	total: 19.8s	remaining: 1m 10s
# 220:	learn: 0.3910160	total: 19.9s	remaining: 1m 10s
# 221:	learn: 0.3905099	total: 20s	remaining: 1m 10s
# 222:	learn: 0.3902893	total: 20.1s	remaining: 1m 10s
# 223:	learn: 0.3899978	total: 20.2s	remaining: 1m 10s
# 224:	learn: 0.3895953	total: 20.3s	remaining: 1m 9s
# 225:	learn: 0.3884501	total: 20.4s	remaining: 1m 9s
# 226:	learn: 0.3880606	total: 20.5s	remaining: 1m 9s
# 227:	learn: 0.3872951	total: 20.6s	remaining: 1m 9s
# 228:	learn: 0.3870850	total: 20.7s	remaining: 1m 9s
# 229:	learn: 0.3868799	total: 20.7s	remaining: 1m 9s
# 230:	learn: 0.3866897	total: 20.8s	remaining: 1m 9s
# 231:	learn: 0.3865383	total: 20.9s	remaining: 1m 9s
# 232:	learn: 0.3861545	total: 21s	remaining: 1m 9s
# 233:	learn: 0.3859992	total: 21.1s	remaining: 1m 8s
# 234:	learn: 0.3856965	total: 21.2s	remaining: 1m 8s
# 235:	learn: 0.3854286	total: 21.2s	remaining: 1m 8s
# 236:	learn: 0.3847472	total: 21.3s	remaining: 1m 8s
# 237:	learn: 0.3841762	total: 21.4s	remaining: 1m 8s
# 238:	learn: 0.3840668	total: 21.5s	remaining: 1m 8s
# 239:	learn: 0.3835828	total: 21.6s	remaining: 1m 8s
# 240:	learn: 0.3831806	total: 21.7s	remaining: 1m 8s
# 241:	learn: 0.3827171	total: 21.8s	remaining: 1m 8s
# 242:	learn: 0.3825132	total: 21.9s	remaining: 1m 8s
# 243:	learn: 0.3821786	total: 22s	remaining: 1m 8s
# 244:	learn: 0.3817426	total: 22.1s	remaining: 1m 8s
# 245:	learn: 0.3805034	total: 22.2s	remaining: 1m 8s
# 246:	learn: 0.3801821	total: 22.3s	remaining: 1m 7s
# 247:	learn: 0.3799990	total: 22.4s	remaining: 1m 7s
# 248:	learn: 0.3798443	total: 22.4s	remaining: 1m 7s
# 249:	learn: 0.3795063	total: 22.5s	remaining: 1m 7s
# 250:	learn: 0.3789889	total: 22.6s	remaining: 1m 7s
# 251:	learn: 0.3787382	total: 22.7s	remaining: 1m 7s
# 252:	learn: 0.3784795	total: 22.8s	remaining: 1m 7s
# 253:	learn: 0.3782699	total: 22.9s	remaining: 1m 7s
# 254:	learn: 0.3780439	total: 23s	remaining: 1m 7s
# 255:	learn: 0.3776452	total: 23.1s	remaining: 1m 7s
# 256:	learn: 0.3775180	total: 23.2s	remaining: 1m 7s
# 257:	learn: 0.3773438	total: 23.3s	remaining: 1m 6s
# 258:	learn: 0.3771981	total: 23.4s	remaining: 1m 6s
# 259:	learn: 0.3770513	total: 23.4s	remaining: 1m 6s
# 260:	learn: 0.3762702	total: 23.5s	remaining: 1m 6s
# 261:	learn: 0.3760082	total: 23.6s	remaining: 1m 6s
# 262:	learn: 0.3757239	total: 23.7s	remaining: 1m 6s
# 263:	learn: 0.3754662	total: 23.8s	remaining: 1m 6s
# 264:	learn: 0.3753342	total: 23.8s	remaining: 1m 6s
# 265:	learn: 0.3751319	total: 23.9s	remaining: 1m 6s
# 266:	learn: 0.3745489	total: 24s	remaining: 1m 5s
# 267:	learn: 0.3743318	total: 24.1s	remaining: 1m 5s
# 268:	learn: 0.3740901	total: 24.2s	remaining: 1m 5s
# 269:	learn: 0.3738153	total: 24.3s	remaining: 1m 5s
# 270:	learn: 0.3732797	total: 24.4s	remaining: 1m 5s
# 271:	learn: 0.3730367	total: 24.5s	remaining: 1m 5s
# 272:	learn: 0.3728169	total: 24.6s	remaining: 1m 5s
# 273:	learn: 0.3727661	total: 24.7s	remaining: 1m 5s
# 274:	learn: 0.3725791	total: 24.8s	remaining: 1m 5s
# 275:	learn: 0.3722225	total: 24.9s	remaining: 1m 5s
# 276:	learn: 0.3720292	total: 24.9s	remaining: 1m 5s
# 277:	learn: 0.3719318	total: 25s	remaining: 1m 4s
# 278:	learn: 0.3717998	total: 25.1s	remaining: 1m 4s
# 279:	learn: 0.3711690	total: 25.2s	remaining: 1m 4s
# 280:	learn: 0.3707864	total: 25.3s	remaining: 1m 4s
# 281:	learn: 0.3705676	total: 25.4s	remaining: 1m 4s
# 282:	learn: 0.3703521	total: 25.5s	remaining: 1m 4s
# 283:	learn: 0.3702597	total: 25.6s	remaining: 1m 4s
# 284:	learn: 0.3701563	total: 25.7s	remaining: 1m 4s
# 285:	learn: 0.3699286	total: 25.8s	remaining: 1m 4s
# 286:	learn: 0.3696041	total: 25.8s	remaining: 1m 4s
# 287:	learn: 0.3695262	total: 25.9s	remaining: 1m 4s
# 288:	learn: 0.3690264	total: 26s	remaining: 1m 4s
# 289:	learn: 0.3689742	total: 26.1s	remaining: 1m 3s
# 290:	learn: 0.3688518	total: 26.2s	remaining: 1m 3s
# 291:	learn: 0.3685669	total: 26.3s	remaining: 1m 3s
# 292:	learn: 0.3685162	total: 26.4s	remaining: 1m 3s
# 293:	learn: 0.3682891	total: 26.5s	remaining: 1m 3s
# 294:	learn: 0.3680882	total: 26.5s	remaining: 1m 3s
# 295:	learn: 0.3679990	total: 26.6s	remaining: 1m 3s
# 296:	learn: 0.3678531	total: 26.7s	remaining: 1m 3s
# 297:	learn: 0.3677507	total: 26.8s	remaining: 1m 3s
# 298:	learn: 0.3676139	total: 26.9s	remaining: 1m 3s
# 299:	learn: 0.3673991	total: 27s	remaining: 1m 2s
# 300:	learn: 0.3669698	total: 27.1s	remaining: 1m 2s
# 301:	learn: 0.3669110	total: 27.2s	remaining: 1m 2s
# 302:	learn: 0.3667232	total: 27.2s	remaining: 1m 2s
# 303:	learn: 0.3665502	total: 27.3s	remaining: 1m 2s
# 304:	learn: 0.3663927	total: 27.4s	remaining: 1m 2s
# 305:	learn: 0.3657573	total: 27.5s	remaining: 1m 2s
# 306:	learn: 0.3654785	total: 27.6s	remaining: 1m 2s
# 307:	learn: 0.3653840	total: 27.6s	remaining: 1m 2s
# 308:	learn: 0.3650438	total: 27.7s	remaining: 1m 2s
# 309:	learn: 0.3649022	total: 27.8s	remaining: 1m 1s
# 310:	learn: 0.3642952	total: 27.9s	remaining: 1m 1s
# 311:	learn: 0.3641652	total: 28s	remaining: 1m 1s
# 312:	learn: 0.3637331	total: 28.1s	remaining: 1m 1s
# 313:	learn: 0.3636470	total: 28.2s	remaining: 1m 1s
# 314:	learn: 0.3635032	total: 28.2s	remaining: 1m 1s
# 315:	learn: 0.3633834	total: 28.4s	remaining: 1m 1s
# 316:	learn: 0.3631741	total: 28.5s	remaining: 1m 1s
# 317:	learn: 0.3629201	total: 28.5s	remaining: 1m 1s
# 318:	learn: 0.3626600	total: 28.6s	remaining: 1m 1s
# 319:	learn: 0.3625261	total: 28.7s	remaining: 1m 1s
# 320:	learn: 0.3621722	total: 28.8s	remaining: 1m
# 321:	learn: 0.3620908	total: 28.9s	remaining: 1m
# 322:	learn: 0.3616159	total: 29s	remaining: 1m
# 323:	learn: 0.3615441	total: 29.1s	remaining: 1m
# 324:	learn: 0.3614184	total: 29.2s	remaining: 1m
# 325:	learn: 0.3613455	total: 29.2s	remaining: 1m
# 326:	learn: 0.3612761	total: 29.3s	remaining: 1m
# 327:	learn: 0.3611278	total: 29.4s	remaining: 1m
# 328:	learn: 0.3609714	total: 29.5s	remaining: 1m
# 329:	learn: 0.3604536	total: 29.6s	remaining: 1m
# 330:	learn: 0.3602313	total: 29.7s	remaining: 1m
# 331:	learn: 0.3599794	total: 29.8s	remaining: 1m
# 332:	learn: 0.3597699	total: 29.9s	remaining: 59.9s
# 333:	learn: 0.3590817	total: 30s	remaining: 59.8s
# 334:	learn: 0.3589600	total: 30.1s	remaining: 59.8s
# 335:	learn: 0.3589010	total: 30.2s	remaining: 59.7s
# 336:	learn: 0.3587980	total: 30.3s	remaining: 59.6s
# 337:	learn: 0.3584135	total: 30.4s	remaining: 59.5s
# 338:	learn: 0.3582013	total: 30.5s	remaining: 59.4s
# 339:	learn: 0.3580060	total: 30.6s	remaining: 59.4s
# 340:	learn: 0.3579268	total: 30.7s	remaining: 59.3s
# 341:	learn: 0.3576793	total: 30.8s	remaining: 59.2s
# 342:	learn: 0.3574982	total: 30.9s	remaining: 59.1s
# 343:	learn: 0.3573141	total: 31s	remaining: 59s
# 344:	learn: 0.3571611	total: 31.1s	remaining: 59s
# 345:	learn: 0.3570143	total: 31.2s	remaining: 58.9s
# 346:	learn: 0.3568692	total: 31.2s	remaining: 58.8s
# 347:	learn: 0.3567520	total: 31.3s	remaining: 58.7s
# 348:	learn: 0.3565803	total: 31.4s	remaining: 58.6s
# 349:	learn: 0.3564278	total: 31.5s	remaining: 58.6s
# 350:	learn: 0.3563293	total: 31.6s	remaining: 58.5s
# 351:	learn: 0.3559819	total: 31.7s	remaining: 58.4s
# 352:	learn: 0.3558737	total: 31.8s	remaining: 58.3s
# 353:	learn: 0.3558146	total: 31.9s	remaining: 58.2s
# 354:	learn: 0.3557386	total: 32s	remaining: 58.1s
# 355:	learn: 0.3556748	total: 32.1s	remaining: 58.1s
# 356:	learn: 0.3556041	total: 32.2s	remaining: 58s
# 357:	learn: 0.3554239	total: 32.3s	remaining: 57.9s
# 358:	learn: 0.3553648	total: 32.4s	remaining: 57.8s
# 359:	learn: 0.3551677	total: 32.5s	remaining: 57.7s
# 360:	learn: 0.3549947	total: 32.6s	remaining: 57.7s
# 361:	learn: 0.3548487	total: 32.7s	remaining: 57.6s
# 362:	learn: 0.3547440	total: 32.8s	remaining: 57.5s
# 363:	learn: 0.3546723	total: 32.9s	remaining: 57.4s
# 364:	learn: 0.3546340	total: 32.9s	remaining: 57.3s
# 365:	learn: 0.3545860	total: 33s	remaining: 57.2s
# 366:	learn: 0.3545298	total: 33.1s	remaining: 57.1s
# 367:	learn: 0.3545022	total: 33.2s	remaining: 57.1s
# 368:	learn: 0.3544549	total: 33.3s	remaining: 57s
# 369:	learn: 0.3543716	total: 33.4s	remaining: 56.9s
# 370:	learn: 0.3543070	total: 33.5s	remaining: 56.8s
# 371:	learn: 0.3542354	total: 33.6s	remaining: 56.7s
# 372:	learn: 0.3541792	total: 33.7s	remaining: 56.6s
# 373:	learn: 0.3541326	total: 33.8s	remaining: 56.5s
# 374:	learn: 0.3540521	total: 33.9s	remaining: 56.5s
# 375:	learn: 0.3540090	total: 34s	remaining: 56.4s
# 376:	learn: 0.3539452	total: 34.1s	remaining: 56.3s
# 377:	learn: 0.3539118	total: 34.1s	remaining: 56.2s
# 378:	learn: 0.3537875	total: 34.2s	remaining: 56.1s
# 379:	learn: 0.3537628	total: 34.3s	remaining: 56s
# 380:	learn: 0.3536463	total: 34.4s	remaining: 55.9s
# 381:	learn: 0.3536003	total: 34.5s	remaining: 55.9s
# 382:	learn: 0.3535390	total: 34.6s	remaining: 55.8s
# 383:	learn: 0.3535164	total: 34.7s	remaining: 55.7s
# 384:	learn: 0.3534975	total: 34.8s	remaining: 55.6s
# 385:	learn: 0.3534816	total: 34.9s	remaining: 55.5s
# 386:	learn: 0.3534683	total: 35s	remaining: 55.4s
# 387:	learn: 0.3533996	total: 35.1s	remaining: 55.4s
# 388:	learn: 0.3533923	total: 35.2s	remaining: 55.3s
# 389:	learn: 0.3533377	total: 35.3s	remaining: 55.2s
# 390:	learn: 0.3533317	total: 35.4s	remaining: 55.1s
# 391:	learn: 0.3533266	total: 35.5s	remaining: 55s
# 392:	learn: 0.3533070	total: 35.6s	remaining: 54.9s
# 393:	learn: 0.3532961	total: 35.6s	remaining: 54.8s
# 394:	learn: 0.3532570	total: 35.7s	remaining: 54.7s
# 395:	learn: 0.3532402	total: 35.8s	remaining: 54.6s
# 396:	learn: 0.3532252	total: 35.9s	remaining: 54.6s
# 397:	learn: 0.3532125	total: 36s	remaining: 54.5s
# 398:	learn: 0.3531604	total: 36.1s	remaining: 54.4s
# 399:	learn: 0.3531570	total: 36.2s	remaining: 54.3s
# 400:	learn: 0.3531541	total: 36.3s	remaining: 54.2s
# 401:	learn: 0.3531517	total: 36.4s	remaining: 54.1s
# 402:	learn: 0.3531410	total: 36.5s	remaining: 54s
# 403:	learn: 0.3531320	total: 36.6s	remaining: 53.9s
# 404:	learn: 0.3531164	total: 36.6s	remaining: 53.8s
# 405:	learn: 0.3531088	total: 36.7s	remaining: 53.7s
# 406:	learn: 0.3531023	total: 36.8s	remaining: 53.6s
# 407:	learn: 0.3530816	total: 36.9s	remaining: 53.6s
# 408:	learn: 0.3530600	total: 37s	remaining: 53.5s
# 409:	learn: 0.3530581	total: 37.1s	remaining: 53.4s
# 410:	learn: 0.3530567	total: 37.2s	remaining: 53.3s
# 411:	learn: 0.3530359	total: 37.3s	remaining: 53.2s
# 412:	learn: 0.3530309	total: 37.4s	remaining: 53.1s
# 413:	learn: 0.3530268	total: 37.4s	remaining: 53s
# 414:	learn: 0.3530213	total: 37.5s	remaining: 52.9s
# 415:	learn: 0.3530086	total: 37.6s	remaining: 52.8s
# 416:	learn: 0.3530041	total: 37.7s	remaining: 52.7s
# 417:	learn: 0.3530003	total: 37.8s	remaining: 52.6s
# 418:	learn: 0.3529481	total: 37.9s	remaining: 52.5s
# 419:	learn: 0.3529313	total: 38s	remaining: 52.4s
# 420:	learn: 0.3529281	total: 38.1s	remaining: 52.4s
# 421:	learn: 0.3529238	total: 38.2s	remaining: 52.3s
# 422:	learn: 0.3529206	total: 38.3s	remaining: 52.2s
# 423:	learn: 0.3529169	total: 38.3s	remaining: 52.1s
# 424:	learn: 0.3529138	total: 38.4s	remaining: 52s
# 425:	learn: 0.3529112	total: 38.5s	remaining: 51.9s
# 426:	learn: 0.3529085	total: 38.6s	remaining: 51.8s
# 427:	learn: 0.3528767	total: 38.7s	remaining: 51.7s
# 428:	learn: 0.3528742	total: 38.8s	remaining: 51.7s
# 429:	learn: 0.3528594	total: 38.9s	remaining: 51.6s
# 430:	learn: 0.3528574	total: 39s	remaining: 51.5s
# 431:	learn: 0.3528555	total: 39.1s	remaining: 51.4s
# 432:	learn: 0.3528440	total: 39.2s	remaining: 51.3s
# 433:	learn: 0.3528424	total: 39.3s	remaining: 51.2s
# 434:	learn: 0.3528408	total: 39.4s	remaining: 51.1s
# 435:	learn: 0.3528312	total: 39.5s	remaining: 51s
# 436:	learn: 0.3528299	total: 39.5s	remaining: 51s
# 437:	learn: 0.3528218	total: 39.6s	remaining: 50.9s
# 438:	learn: 0.3528149	total: 39.7s	remaining: 50.8s
# 439:	learn: 0.3528092	total: 39.8s	remaining: 50.7s
# 440:	learn: 0.3528042	total: 39.9s	remaining: 50.6s
# 441:	learn: 0.3528027	total: 40s	remaining: 50.5s
# 442:	learn: 0.3528018	total: 40.1s	remaining: 50.4s
# 443:	learn: 0.3521379	total: 40.2s	remaining: 50.3s
# 444:	learn: 0.3521228	total: 40.3s	remaining: 50.3s
# 445:	learn: 0.3519534	total: 40.4s	remaining: 50.2s
# 446:	learn: 0.3519525	total: 40.5s	remaining: 50.1s
# 447:	learn: 0.3519414	total: 40.6s	remaining: 50s
# 448:	learn: 0.3519328	total: 40.7s	remaining: 49.9s
# 449:	learn: 0.3519143	total: 40.8s	remaining: 49.8s
# 450:	learn: 0.3519104	total: 40.9s	remaining: 49.7s
# 451:	learn: 0.3519071	total: 41s	remaining: 49.7s
# 452:	learn: 0.3519047	total: 41s	remaining: 49.6s
# 453:	learn: 0.3519034	total: 41.1s	remaining: 49.5s
# 454:	learn: 0.3519013	total: 41.2s	remaining: 49.4s
# 455:	learn: 0.3518984	total: 41.3s	remaining: 49.3s
# 456:	learn: 0.3518959	total: 41.4s	remaining: 49.2s
# 457:	learn: 0.3518953	total: 41.5s	remaining: 49.1s
# 458:	learn: 0.3518941	total: 41.6s	remaining: 49s
# 459:	learn: 0.3518920	total: 41.7s	remaining: 49s
# 460:	learn: 0.3518910	total: 41.8s	remaining: 48.9s
# 461:	learn: 0.3518892	total: 41.9s	remaining: 48.8s
# 462:	learn: 0.3518779	total: 42s	remaining: 48.7s
# 463:	learn: 0.3518764	total: 42.1s	remaining: 48.6s
# 464:	learn: 0.3518758	total: 42.2s	remaining: 48.5s
# 465:	learn: 0.3518749	total: 42.3s	remaining: 48.4s
# 466:	learn: 0.3518742	total: 42.4s	remaining: 48.3s
# 467:	learn: 0.3518729	total: 42.4s	remaining: 48.2s
# 468:	learn: 0.3518718	total: 42.5s	remaining: 48.2s
# 469:	learn: 0.3518698	total: 42.6s	remaining: 48.1s
# 470:	learn: 0.3518692	total: 42.7s	remaining: 48s
# 471:	learn: 0.3518686	total: 42.8s	remaining: 47.9s
# 472:	learn: 0.3518680	total: 42.9s	remaining: 47.8s
# 473:	learn: 0.3518670	total: 43s	remaining: 47.7s
# 474:	learn: 0.3518662	total: 43.1s	remaining: 47.6s
# 475:	learn: 0.3518655	total: 43.2s	remaining: 47.5s
# 476:	learn: 0.3518650	total: 43.3s	remaining: 47.4s
# 477:	learn: 0.3518645	total: 43.4s	remaining: 47.3s
# 478:	learn: 0.3518639	total: 43.5s	remaining: 47.3s
# 479:	learn: 0.3518635	total: 43.5s	remaining: 47.2s
# 480:	learn: 0.3518632	total: 43.6s	remaining: 47.1s
# 481:	learn: 0.3518612	total: 43.7s	remaining: 47s
# 482:	learn: 0.3518608	total: 43.8s	remaining: 46.9s
# 483:	learn: 0.3518604	total: 43.9s	remaining: 46.8s
# 484:	learn: 0.3518599	total: 44s	remaining: 46.7s
# 485:	learn: 0.3518595	total: 44.1s	remaining: 46.6s
# 486:	learn: 0.3518592	total: 44.2s	remaining: 46.5s
# 487:	learn: 0.3518589	total: 44.3s	remaining: 46.4s
# 488:	learn: 0.3518433	total: 44.4s	remaining: 46.4s
# 489:	learn: 0.3518431	total: 44.4s	remaining: 46.3s
# 490:	learn: 0.3518427	total: 44.5s	remaining: 46.2s
# 491:	learn: 0.3518425	total: 44.6s	remaining: 46.1s
# 492:	learn: 0.3518422	total: 44.7s	remaining: 46s
# 493:	learn: 0.3518420	total: 44.8s	remaining: 45.9s
# 494:	learn: 0.3518418	total: 44.9s	remaining: 45.8s
# 495:	learn: 0.3518412	total: 45s	remaining: 45.7s
# 496:	learn: 0.3518410	total: 45.1s	remaining: 45.6s
# 497:	learn: 0.3518408	total: 45.2s	remaining: 45.5s
# 498:	learn: 0.3518406	total: 45.3s	remaining: 45.4s
# 499:	learn: 0.3518404	total: 45.4s	remaining: 45.4s
# 500:	learn: 0.3518403	total: 45.5s	remaining: 45.3s
# 501:	learn: 0.3518402	total: 45.5s	remaining: 45.2s
# 502:	learn: 0.3518399	total: 45.6s	remaining: 45.1s
# 503:	learn: 0.3518399	total: 45.7s	remaining: 45s
# 504:	learn: 0.3518397	total: 45.8s	remaining: 44.9s
# 505:	learn: 0.3518395	total: 45.9s	remaining: 44.8s
# 506:	learn: 0.3518395	total: 46s	remaining: 44.7s
# 507:	learn: 0.3518394	total: 46.1s	remaining: 44.6s
# 508:	learn: 0.3518393	total: 46.2s	remaining: 44.5s
# 509:	learn: 0.3518392	total: 46.3s	remaining: 44.4s
# 510:	learn: 0.3518391	total: 46.3s	remaining: 44.4s
# 511:	learn: 0.3518386	total: 46.4s	remaining: 44.3s
# 512:	learn: 0.3518385	total: 46.5s	remaining: 44.2s
# 513:	learn: 0.3518385	total: 46.6s	remaining: 44.1s
# 514:	learn: 0.3518314	total: 46.7s	remaining: 44s
# 515:	learn: 0.3518313	total: 46.8s	remaining: 43.9s
# 516:	learn: 0.3518312	total: 46.9s	remaining: 43.8s
# 517:	learn: 0.3518311	total: 47s	remaining: 43.7s
# 518:	learn: 0.3518311	total: 47.1s	remaining: 43.6s
# 519:	learn: 0.3518310	total: 47.2s	remaining: 43.5s
# 520:	learn: 0.3518309	total: 47.3s	remaining: 43.5s
# 521:	learn: 0.3518308	total: 47.4s	remaining: 43.4s
# 522:	learn: 0.3518308	total: 47.4s	remaining: 43.3s
# 523:	learn: 0.3518307	total: 47.5s	remaining: 43.2s
# 524:	learn: 0.3518307	total: 47.6s	remaining: 43.1s
# 525:	learn: 0.3518305	total: 47.7s	remaining: 43s
# 526:	learn: 0.3518305	total: 47.8s	remaining: 42.9s
# 527:	learn: 0.3518305	total: 47.9s	remaining: 42.8s
# 528:	learn: 0.3518305	total: 48s	remaining: 42.7s
# 529:	learn: 0.3518305	total: 48.1s	remaining: 42.7s
# 530:	learn: 0.3518304	total: 48.2s	remaining: 42.6s
# 531:	learn: 0.3518304	total: 48.3s	remaining: 42.5s
# 532:	learn: 0.3518303	total: 48.4s	remaining: 42.4s
# 533:	learn: 0.3518302	total: 48.5s	remaining: 42.3s
# 534:	learn: 0.3518303	total: 48.6s	remaining: 42.2s
# 535:	learn: 0.3518302	total: 48.7s	remaining: 42.1s
# 536:	learn: 0.3518302	total: 48.8s	remaining: 42s
# 537:	learn: 0.3518302	total: 48.8s	remaining: 41.9s
# 538:	learn: 0.3518302	total: 48.9s	remaining: 41.9s
# 539:	learn: 0.3518301	total: 49s	remaining: 41.8s
# 540:	learn: 0.3518301	total: 49.1s	remaining: 41.7s
# 541:	learn: 0.3518301	total: 49.2s	remaining: 41.6s
# 542:	learn: 0.3518301	total: 49.3s	remaining: 41.5s
# 543:	learn: 0.3518301	total: 49.4s	remaining: 41.4s
# 544:	learn: 0.3518300	total: 49.5s	remaining: 41.3s
# 545:	learn: 0.3518225	total: 49.6s	remaining: 41.2s
# 546:	learn: 0.3518224	total: 49.7s	remaining: 41.1s
# 547:	learn: 0.3518224	total: 49.8s	remaining: 41.1s
# 548:	learn: 0.3518223	total: 49.9s	remaining: 41s
# 549:	learn: 0.3518223	total: 50s	remaining: 40.9s
# 550:	learn: 0.3518223	total: 50s	remaining: 40.8s
# 551:	learn: 0.3518223	total: 50.1s	remaining: 40.7s
# 552:	learn: 0.3518223	total: 50.2s	remaining: 40.6s
# 553:	learn: 0.3518222	total: 50.3s	remaining: 40.5s
# 554:	learn: 0.3518222	total: 50.4s	remaining: 40.4s
# 555:	learn: 0.3518222	total: 50.5s	remaining: 40.3s
# 556:	learn: 0.3518222	total: 50.6s	remaining: 40.2s
# 557:	learn: 0.3518222	total: 50.7s	remaining: 40.2s
# 558:	learn: 0.3518222	total: 50.8s	remaining: 40.1s
# 559:	learn: 0.3518222	total: 50.9s	remaining: 40s
# 560:	learn: 0.3518222	total: 51s	remaining: 39.9s
# 561:	learn: 0.3518221	total: 51.1s	remaining: 39.8s
# 562:	learn: 0.3518221	total: 51.1s	remaining: 39.7s
# 563:	learn: 0.3518220	total: 51.2s	remaining: 39.6s
# 564:	learn: 0.3518220	total: 51.3s	remaining: 39.5s
# 565:	learn: 0.3518221	total: 51.4s	remaining: 39.4s
# 566:	learn: 0.3518220	total: 51.5s	remaining: 39.3s
# 567:	learn: 0.3518221	total: 51.6s	remaining: 39.3s
# 568:	learn: 0.3518220	total: 51.7s	remaining: 39.2s
# 569:	learn: 0.3518220	total: 51.8s	remaining: 39.1s
# 570:	learn: 0.3518220	total: 51.9s	remaining: 39s
# 571:	learn: 0.3518220	total: 52s	remaining: 38.9s
# 572:	learn: 0.3518220	total: 52.1s	remaining: 38.8s
# 573:	learn: 0.3518219	total: 52.2s	remaining: 38.7s
# 574:	learn: 0.3518219	total: 52.3s	remaining: 38.6s
# 575:	learn: 0.3518220	total: 52.4s	remaining: 38.5s
# 576:	learn: 0.3518219	total: 52.5s	remaining: 38.5s
# 577:	learn: 0.3518220	total: 52.5s	remaining: 38.4s
# 578:	learn: 0.3518219	total: 52.6s	remaining: 38.3s
# 579:	learn: 0.3518219	total: 52.7s	remaining: 38.2s
# 580:	learn: 0.3518219	total: 52.8s	remaining: 38.1s
# 581:	learn: 0.3518219	total: 52.9s	remaining: 38s
# 582:	learn: 0.3518219	total: 53s	remaining: 37.9s
# 583:	learn: 0.3518219	total: 53.1s	remaining: 37.8s
# 584:	learn: 0.3518219	total: 53.2s	remaining: 37.7s
# 585:	learn: 0.3518218	total: 53.3s	remaining: 37.6s
# 586:	learn: 0.3518219	total: 53.4s	remaining: 37.5s
# 587:	learn: 0.3518218	total: 53.5s	remaining: 37.5s
# 588:	learn: 0.3518218	total: 53.6s	remaining: 37.4s
# 589:	learn: 0.3518219	total: 53.6s	remaining: 37.3s
# 590:	learn: 0.3518218	total: 53.7s	remaining: 37.2s
# 591:	learn: 0.3518214	total: 53.8s	remaining: 37.1s
# 592:	learn: 0.3518214	total: 53.9s	remaining: 37s
# 593:	learn: 0.3518214	total: 54s	remaining: 36.9s
# 594:	learn: 0.3518213	total: 54.1s	remaining: 36.8s
# 595:	learn: 0.3518213	total: 54.2s	remaining: 36.7s
# 596:	learn: 0.3518213	total: 54.3s	remaining: 36.6s
# 597:	learn: 0.3518213	total: 54.4s	remaining: 36.6s
# 598:	learn: 0.3518213	total: 54.5s	remaining: 36.5s
# 599:	learn: 0.3518213	total: 54.6s	remaining: 36.4s
# 600:	learn: 0.3518213	total: 54.6s	remaining: 36.3s
# 601:	learn: 0.3518213	total: 54.7s	remaining: 36.2s
# 602:	learn: 0.3518213	total: 54.8s	remaining: 36.1s
# 603:	learn: 0.3518214	total: 54.9s	remaining: 36s
# 604:	learn: 0.3518213	total: 55s	remaining: 35.9s
# 605:	learn: 0.3518214	total: 55.1s	remaining: 35.8s
# 606:	learn: 0.3518214	total: 55.2s	remaining: 35.7s
# 607:	learn: 0.3518213	total: 55.3s	remaining: 35.6s
# 608:	learn: 0.3518213	total: 55.4s	remaining: 35.6s
# 609:	learn: 0.3518213	total: 55.5s	remaining: 35.5s
# 610:	learn: 0.3518213	total: 55.6s	remaining: 35.4s
# 611:	learn: 0.3518213	total: 55.7s	remaining: 35.3s
# 612:	learn: 0.3518213	total: 55.8s	remaining: 35.2s
# 613:	learn: 0.3518213	total: 55.8s	remaining: 35.1s
# 614:	learn: 0.3518212	total: 55.9s	remaining: 35s
# 615:	learn: 0.3518212	total: 56s	remaining: 34.9s
# 616:	learn: 0.3518212	total: 56.1s	remaining: 34.8s
# 617:	learn: 0.3518213	total: 56.2s	remaining: 34.7s
# 618:	learn: 0.3518213	total: 56.3s	remaining: 34.6s
# 619:	learn: 0.3518213	total: 56.4s	remaining: 34.6s
# 620:	learn: 0.3518213	total: 56.5s	remaining: 34.5s
# 621:	learn: 0.3518213	total: 56.6s	remaining: 34.4s
# 622:	learn: 0.3518213	total: 56.7s	remaining: 34.3s
# 623:	learn: 0.3518213	total: 56.8s	remaining: 34.2s
# 624:	learn: 0.3518213	total: 56.9s	remaining: 34.1s
# 625:	learn: 0.3518213	total: 56.9s	remaining: 34s
# 626:	learn: 0.3518213	total: 57s	remaining: 33.9s
# 627:	learn: 0.3518213	total: 57.1s	remaining: 33.8s
# 628:	learn: 0.3518213	total: 57.2s	remaining: 33.7s
# 629:	learn: 0.3518213	total: 57.3s	remaining: 33.7s
# 630:	learn: 0.3518213	total: 57.4s	remaining: 33.6s
# 631:	learn: 0.3518213	total: 57.5s	remaining: 33.5s
# 632:	learn: 0.3518213	total: 57.6s	remaining: 33.4s
# 633:	learn: 0.3518213	total: 57.7s	remaining: 33.3s
# 634:	learn: 0.3518213	total: 57.8s	remaining: 33.2s
# 635:	learn: 0.3518213	total: 57.9s	remaining: 33.1s
# 636:	learn: 0.3518212	total: 58s	remaining: 33s
# 637:	learn: 0.3518212	total: 58.1s	remaining: 32.9s
# 638:	learn: 0.3518212	total: 58.1s	remaining: 32.8s
# 639:	learn: 0.3518212	total: 58.2s	remaining: 32.8s
# 640:	learn: 0.3518212	total: 58.3s	remaining: 32.7s
# 641:	learn: 0.3518212	total: 58.4s	remaining: 32.6s
# 642:	learn: 0.3518212	total: 58.5s	remaining: 32.5s
# 643:	learn: 0.3518212	total: 58.6s	remaining: 32.4s
# 644:	learn: 0.3518212	total: 58.7s	remaining: 32.3s
# 645:	learn: 0.3518212	total: 58.8s	remaining: 32.2s
# 646:	learn: 0.3518212	total: 58.9s	remaining: 32.1s
# 647:	learn: 0.3518212	total: 59s	remaining: 32s
# 648:	learn: 0.3518212	total: 59.1s	remaining: 31.9s
# 649:	learn: 0.3518212	total: 59.1s	remaining: 31.8s
# 650:	learn: 0.3518212	total: 59.2s	remaining: 31.8s
# 651:	learn: 0.3518212	total: 59.3s	remaining: 31.7s
# 652:	learn: 0.3518212	total: 59.4s	remaining: 31.6s
# 653:	learn: 0.3518212	total: 59.5s	remaining: 31.5s
# 654:	learn: 0.3518211	total: 59.6s	remaining: 31.4s
# 655:	learn: 0.3518211	total: 59.7s	remaining: 31.3s
# 656:	learn: 0.3518211	total: 59.8s	remaining: 31.2s
# 657:	learn: 0.3518211	total: 59.9s	remaining: 31.1s
# 658:	learn: 0.3518211	total: 60s	remaining: 31s
# 659:	learn: 0.3518211	total: 1m	remaining: 30.9s
# 660:	learn: 0.3518211	total: 1m	remaining: 30.8s
# 661:	learn: 0.3518211	total: 1m	remaining: 30.8s
# 662:	learn: 0.3518211	total: 1m	remaining: 30.7s
# 663:	learn: 0.3518210	total: 1m	remaining: 30.6s
# 664:	learn: 0.3518210	total: 1m	remaining: 30.5s
# 665:	learn: 0.3518210	total: 1m	remaining: 30.4s
# 666:	learn: 0.3518210	total: 1m	remaining: 30.3s
# 667:	learn: 0.3518210	total: 1m	remaining: 30.2s
# 668:	learn: 0.3518210	total: 1m	remaining: 30.1s
# 669:	learn: 0.3518210	total: 1m	remaining: 30s
# 670:	learn: 0.3518210	total: 1m 1s	remaining: 29.9s
# 671:	learn: 0.3518210	total: 1m 1s	remaining: 29.9s
# 672:	learn: 0.3518210	total: 1m 1s	remaining: 29.8s
# 673:	learn: 0.3518210	total: 1m 1s	remaining: 29.7s
# 674:	learn: 0.3518210	total: 1m 1s	remaining: 29.6s
# 675:	learn: 0.3518210	total: 1m 1s	remaining: 29.5s
# 676:	learn: 0.3518210	total: 1m 1s	remaining: 29.4s
# 677:	learn: 0.3518210	total: 1m 1s	remaining: 29.3s
# 678:	learn: 0.3518210	total: 1m 1s	remaining: 29.2s
# 679:	learn: 0.3518210	total: 1m 1s	remaining: 29.1s
# 680:	learn: 0.3518210	total: 1m 1s	remaining: 29s
# 681:	learn: 0.3518210	total: 1m 2s	remaining: 29s
# 682:	learn: 0.3518210	total: 1m 2s	remaining: 28.9s
# 683:	learn: 0.3518210	total: 1m 2s	remaining: 28.8s
# 684:	learn: 0.3518210	total: 1m 2s	remaining: 28.7s
# 685:	learn: 0.3518210	total: 1m 2s	remaining: 28.6s
# 686:	learn: 0.3518210	total: 1m 2s	remaining: 28.5s
# 687:	learn: 0.3518210	total: 1m 2s	remaining: 28.4s
# 688:	learn: 0.3518210	total: 1m 2s	remaining: 28.3s
# 689:	learn: 0.3518210	total: 1m 2s	remaining: 28.2s
# 690:	learn: 0.3518210	total: 1m 2s	remaining: 28.1s
# 691:	learn: 0.3518210	total: 1m 3s	remaining: 28s
# 692:	learn: 0.3518210	total: 1m 3s	remaining: 28s
# 693:	learn: 0.3518210	total: 1m 3s	remaining: 27.9s
# 694:	learn: 0.3518210	total: 1m 3s	remaining: 27.8s
# 695:	learn: 0.3518210	total: 1m 3s	remaining: 27.7s
# 696:	learn: 0.3518210	total: 1m 3s	remaining: 27.6s
# 697:	learn: 0.3518210	total: 1m 3s	remaining: 27.5s
# 698:	learn: 0.3518210	total: 1m 3s	remaining: 27.4s
# 699:	learn: 0.3518210	total: 1m 3s	remaining: 27.3s
# 700:	learn: 0.3518210	total: 1m 3s	remaining: 27.2s
# 701:	learn: 0.3518210	total: 1m 3s	remaining: 27.1s
# 702:	learn: 0.3518210	total: 1m 4s	remaining: 27s
# 703:	learn: 0.3518210	total: 1m 4s	remaining: 27s
# 704:	learn: 0.3518210	total: 1m 4s	remaining: 26.9s
# 705:	learn: 0.3518210	total: 1m 4s	remaining: 26.8s
# 706:	learn: 0.3518210	total: 1m 4s	remaining: 26.7s
# 707:	learn: 0.3518210	total: 1m 4s	remaining: 26.6s
# 708:	learn: 0.3518210	total: 1m 4s	remaining: 26.5s
# 709:	learn: 0.3518210	total: 1m 4s	remaining: 26.4s
# 710:	learn: 0.3518210	total: 1m 4s	remaining: 26.3s
# 711:	learn: 0.3518210	total: 1m 4s	remaining: 26.2s
# 712:	learn: 0.3518210	total: 1m 4s	remaining: 26.1s
# 713:	learn: 0.3518210	total: 1m 5s	remaining: 26s
# 714:	learn: 0.3518210	total: 1m 5s	remaining: 26s
# 715:	learn: 0.3518210	total: 1m 5s	remaining: 25.9s
# 716:	learn: 0.3518210	total: 1m 5s	remaining: 25.8s
# 717:	learn: 0.3518210	total: 1m 5s	remaining: 25.7s
# 718:	learn: 0.3518210	total: 1m 5s	remaining: 25.6s
# 719:	learn: 0.3518210	total: 1m 5s	remaining: 25.5s
# 720:	learn: 0.3518210	total: 1m 5s	remaining: 25.4s
# 721:	learn: 0.3518210	total: 1m 5s	remaining: 25.3s
# 722:	learn: 0.3518210	total: 1m 5s	remaining: 25.2s
# 723:	learn: 0.3518210	total: 1m 5s	remaining: 25.1s
# 724:	learn: 0.3518210	total: 1m 6s	remaining: 25s
# 725:	learn: 0.3518210	total: 1m 6s	remaining: 25s
# 726:	learn: 0.3518210	total: 1m 6s	remaining: 24.9s
# 727:	learn: 0.3518210	total: 1m 6s	remaining: 24.8s
# 728:	learn: 0.3518210	total: 1m 6s	remaining: 24.7s
# 729:	learn: 0.3518210	total: 1m 6s	remaining: 24.6s
# 730:	learn: 0.3518210	total: 1m 6s	remaining: 24.5s
# 731:	learn: 0.3518210	total: 1m 6s	remaining: 24.4s
# 732:	learn: 0.3518210	total: 1m 6s	remaining: 24.3s
# 733:	learn: 0.3518210	total: 1m 6s	remaining: 24.2s
# 734:	learn: 0.3518210	total: 1m 6s	remaining: 24.1s
# 735:	learn: 0.3518210	total: 1m 7s	remaining: 24s
# 736:	learn: 0.3518210	total: 1m 7s	remaining: 23.9s
# 737:	learn: 0.3518210	total: 1m 7s	remaining: 23.9s
# 738:	learn: 0.3518210	total: 1m 7s	remaining: 23.8s
# 739:	learn: 0.3518210	total: 1m 7s	remaining: 23.7s
# 740:	learn: 0.3518210	total: 1m 7s	remaining: 23.6s
# 741:	learn: 0.3518210	total: 1m 7s	remaining: 23.5s
# 742:	learn: 0.3518210	total: 1m 7s	remaining: 23.4s
# 743:	learn: 0.3518210	total: 1m 7s	remaining: 23.3s
# 744:	learn: 0.3518210	total: 1m 7s	remaining: 23.2s
# 745:	learn: 0.3518210	total: 1m 7s	remaining: 23.1s
# 746:	learn: 0.3518210	total: 1m 8s	remaining: 23s
# 747:	learn: 0.3518210	total: 1m 8s	remaining: 23s
# 748:	learn: 0.3518210	total: 1m 8s	remaining: 22.9s
# 749:	learn: 0.3518210	total: 1m 8s	remaining: 22.8s
# 750:	learn: 0.3518210	total: 1m 8s	remaining: 22.7s
# 751:	learn: 0.3518210	total: 1m 8s	remaining: 22.6s
# 752:	learn: 0.3518210	total: 1m 8s	remaining: 22.5s
# 753:	learn: 0.3518210	total: 1m 8s	remaining: 22.4s
# 754:	learn: 0.3518210	total: 1m 8s	remaining: 22.3s
# 755:	learn: 0.3518210	total: 1m 8s	remaining: 22.2s
# 756:	learn: 0.3518210	total: 1m 8s	remaining: 22.1s
# 757:	learn: 0.3518210	total: 1m 9s	remaining: 22s
# 758:	learn: 0.3518210	total: 1m 9s	remaining: 22s
# 759:	learn: 0.3518210	total: 1m 9s	remaining: 21.9s
# 760:	learn: 0.3518210	total: 1m 9s	remaining: 21.8s
# 761:	learn: 0.3518210	total: 1m 9s	remaining: 21.7s
# 762:	learn: 0.3518210	total: 1m 9s	remaining: 21.6s
# 763:	learn: 0.3518210	total: 1m 9s	remaining: 21.5s
# 764:	learn: 0.3518210	total: 1m 9s	remaining: 21.4s
# 765:	learn: 0.3518210	total: 1m 9s	remaining: 21.3s
# 766:	learn: 0.3518210	total: 1m 9s	remaining: 21.2s
# 767:	learn: 0.3518210	total: 1m 9s	remaining: 21.1s
# 768:	learn: 0.3518210	total: 1m 10s	remaining: 21s
# 769:	learn: 0.3518210	total: 1m 10s	remaining: 21s
# 770:	learn: 0.3518210	total: 1m 10s	remaining: 20.9s
# 771:	learn: 0.3518210	total: 1m 10s	remaining: 20.8s
# 772:	learn: 0.3518210	total: 1m 10s	remaining: 20.7s
# 773:	learn: 0.3518210	total: 1m 10s	remaining: 20.6s
# 774:	learn: 0.3518210	total: 1m 10s	remaining: 20.5s
# 775:	learn: 0.3518210	total: 1m 10s	remaining: 20.4s
# 776:	learn: 0.3518210	total: 1m 10s	remaining: 20.3s
# 777:	learn: 0.3518210	total: 1m 10s	remaining: 20.2s
# 778:	learn: 0.3518210	total: 1m 10s	remaining: 20.1s
# 779:	learn: 0.3518210	total: 1m 11s	remaining: 20s
# 780:	learn: 0.3518210	total: 1m 11s	remaining: 20s
# 781:	learn: 0.3518210	total: 1m 11s	remaining: 19.9s
# 782:	learn: 0.3518210	total: 1m 11s	remaining: 19.8s
# 783:	learn: 0.3518210	total: 1m 11s	remaining: 19.7s
# 784:	learn: 0.3518210	total: 1m 11s	remaining: 19.6s
# 785:	learn: 0.3518210	total: 1m 11s	remaining: 19.5s
# 786:	learn: 0.3518210	total: 1m 11s	remaining: 19.4s
# 787:	learn: 0.3518210	total: 1m 11s	remaining: 19.3s
# 788:	learn: 0.3518209	total: 1m 11s	remaining: 19.2s
# 789:	learn: 0.3518209	total: 1m 11s	remaining: 19.1s
# 790:	learn: 0.3518209	total: 1m 12s	remaining: 19s
# 791:	learn: 0.3518209	total: 1m 12s	remaining: 19s
# 792:	learn: 0.3518209	total: 1m 12s	remaining: 18.9s
# 793:	learn: 0.3518209	total: 1m 12s	remaining: 18.8s
# 794:	learn: 0.3518209	total: 1m 12s	remaining: 18.7s
# 795:	learn: 0.3518209	total: 1m 12s	remaining: 18.6s
# 796:	learn: 0.3518209	total: 1m 12s	remaining: 18.5s
# 797:	learn: 0.3518209	total: 1m 12s	remaining: 18.4s
# 798:	learn: 0.3518209	total: 1m 12s	remaining: 18.3s
# 799:	learn: 0.3518209	total: 1m 12s	remaining: 18.2s
# 800:	learn: 0.3518209	total: 1m 13s	remaining: 18.1s
# 801:	learn: 0.3518209	total: 1m 13s	remaining: 18s
# 802:	learn: 0.3518210	total: 1m 13s	remaining: 18s
# 803:	learn: 0.3518209	total: 1m 13s	remaining: 17.9s
# 804:	learn: 0.3518210	total: 1m 13s	remaining: 17.8s
# 805:	learn: 0.3518210	total: 1m 13s	remaining: 17.7s
# 806:	learn: 0.3518209	total: 1m 13s	remaining: 17.6s
# 807:	learn: 0.3518210	total: 1m 13s	remaining: 17.5s
# 808:	learn: 0.3518210	total: 1m 13s	remaining: 17.4s
# 809:	learn: 0.3518210	total: 1m 13s	remaining: 17.3s
# 810:	learn: 0.3518209	total: 1m 13s	remaining: 17.2s
# 811:	learn: 0.3518210	total: 1m 14s	remaining: 17.1s
# 812:	learn: 0.3518209	total: 1m 14s	remaining: 17s
# 813:	learn: 0.3518209	total: 1m 14s	remaining: 17s
# 814:	learn: 0.3518210	total: 1m 14s	remaining: 16.9s
# 815:	learn: 0.3518210	total: 1m 14s	remaining: 16.8s
# 816:	learn: 0.3518210	total: 1m 14s	remaining: 16.7s
# 817:	learn: 0.3518209	total: 1m 14s	remaining: 16.6s
# 818:	learn: 0.3518209	total: 1m 14s	remaining: 16.5s
# 819:	learn: 0.3518209	total: 1m 14s	remaining: 16.4s
# 820:	learn: 0.3518209	total: 1m 14s	remaining: 16.3s
# 821:	learn: 0.3518209	total: 1m 14s	remaining: 16.2s
# 822:	learn: 0.3518209	total: 1m 15s	remaining: 16.1s
# 823:	learn: 0.3518209	total: 1m 15s	remaining: 16s
# 824:	learn: 0.3518209	total: 1m 15s	remaining: 15.9s
# 825:	learn: 0.3518209	total: 1m 15s	remaining: 15.9s
# 826:	learn: 0.3518209	total: 1m 15s	remaining: 15.8s
# 827:	learn: 0.3518209	total: 1m 15s	remaining: 15.7s
# 828:	learn: 0.3518209	total: 1m 15s	remaining: 15.6s
# 829:	learn: 0.3518209	total: 1m 15s	remaining: 15.5s
# 830:	learn: 0.3518209	total: 1m 15s	remaining: 15.4s
# 831:	learn: 0.3518209	total: 1m 15s	remaining: 15.3s
# 832:	learn: 0.3518208	total: 1m 15s	remaining: 15.2s
# 833:	learn: 0.3518209	total: 1m 16s	remaining: 15.1s
# 834:	learn: 0.3518209	total: 1m 16s	remaining: 15s
# 835:	learn: 0.3518209	total: 1m 16s	remaining: 15s
# 836:	learn: 0.3518209	total: 1m 16s	remaining: 14.9s
# 837:	learn: 0.3518209	total: 1m 16s	remaining: 14.8s
# 838:	learn: 0.3518209	total: 1m 16s	remaining: 14.7s
# 839:	learn: 0.3518209	total: 1m 16s	remaining: 14.6s
# 840:	learn: 0.3518209	total: 1m 16s	remaining: 14.5s
# 841:	learn: 0.3518209	total: 1m 16s	remaining: 14.4s
# 842:	learn: 0.3518209	total: 1m 16s	remaining: 14.3s
# 843:	learn: 0.3518209	total: 1m 16s	remaining: 14.2s
# 844:	learn: 0.3518209	total: 1m 17s	remaining: 14.1s
# 845:	learn: 0.3518209	total: 1m 17s	remaining: 14s
# 846:	learn: 0.3518209	total: 1m 17s	remaining: 14s
# 847:	learn: 0.3518209	total: 1m 17s	remaining: 13.9s
# 848:	learn: 0.3518209	total: 1m 17s	remaining: 13.8s
# 849:	learn: 0.3518209	total: 1m 17s	remaining: 13.7s
# 850:	learn: 0.3518209	total: 1m 17s	remaining: 13.6s
# 851:	learn: 0.3518209	total: 1m 17s	remaining: 13.5s
# 852:	learn: 0.3518209	total: 1m 17s	remaining: 13.4s
# 853:	learn: 0.3518209	total: 1m 17s	remaining: 13.3s
# 854:	learn: 0.3518209	total: 1m 17s	remaining: 13.2s
# 855:	learn: 0.3518209	total: 1m 18s	remaining: 13.1s
# 856:	learn: 0.3518209	total: 1m 18s	remaining: 13s
# 857:	learn: 0.3518209	total: 1m 18s	remaining: 13s
# 858:	learn: 0.3518209	total: 1m 18s	remaining: 12.9s
# 859:	learn: 0.3518209	total: 1m 18s	remaining: 12.8s
# 860:	learn: 0.3518209	total: 1m 18s	remaining: 12.7s
# 861:	learn: 0.3518209	total: 1m 18s	remaining: 12.6s
# 862:	learn: 0.3518209	total: 1m 18s	remaining: 12.5s
# 863:	learn: 0.3518209	total: 1m 18s	remaining: 12.4s
# 864:	learn: 0.3518209	total: 1m 18s	remaining: 12.3s
# 865:	learn: 0.3518209	total: 1m 19s	remaining: 12.2s
# 866:	learn: 0.3518209	total: 1m 19s	remaining: 12.1s
# 867:	learn: 0.3518209	total: 1m 19s	remaining: 12s
# 868:	learn: 0.3518209	total: 1m 19s	remaining: 12s
# 869:	learn: 0.3518209	total: 1m 19s	remaining: 11.9s
# 870:	learn: 0.3518209	total: 1m 19s	remaining: 11.8s
# 871:	learn: 0.3518209	total: 1m 19s	remaining: 11.7s
# 872:	learn: 0.3518209	total: 1m 19s	remaining: 11.6s
# 873:	learn: 0.3518209	total: 1m 19s	remaining: 11.5s
# 874:	learn: 0.3518208	total: 1m 19s	remaining: 11.4s
# 875:	learn: 0.3518208	total: 1m 19s	remaining: 11.3s
# 876:	learn: 0.3518208	total: 1m 20s	remaining: 11.2s
# 877:	learn: 0.3518208	total: 1m 20s	remaining: 11.1s
# 878:	learn: 0.3518208	total: 1m 20s	remaining: 11s
# 879:	learn: 0.3518209	total: 1m 20s	remaining: 11s
# 880:	learn: 0.3518208	total: 1m 20s	remaining: 10.9s
# 881:	learn: 0.3518208	total: 1m 20s	remaining: 10.8s
# 882:	learn: 0.3518208	total: 1m 20s	remaining: 10.7s
# 883:	learn: 0.3518209	total: 1m 20s	remaining: 10.6s
# 884:	learn: 0.3518208	total: 1m 20s	remaining: 10.5s
# 885:	learn: 0.3518208	total: 1m 20s	remaining: 10.4s
# 886:	learn: 0.3518208	total: 1m 21s	remaining: 10.3s
# 887:	learn: 0.3518208	total: 1m 21s	remaining: 10.2s
# 888:	learn: 0.3518208	total: 1m 21s	remaining: 10.1s
# 889:	learn: 0.3518208	total: 1m 21s	remaining: 10s
# 890:	learn: 0.3518208	total: 1m 21s	remaining: 9.96s
# 891:	learn: 0.3518208	total: 1m 21s	remaining: 9.86s
# 892:	learn: 0.3518208	total: 1m 21s	remaining: 9.77s
# 893:	learn: 0.3518208	total: 1m 21s	remaining: 9.68s
# 894:	learn: 0.3518208	total: 1m 21s	remaining: 9.59s
# 895:	learn: 0.3518208	total: 1m 21s	remaining: 9.5s
# 896:	learn: 0.3518209	total: 1m 21s	remaining: 9.41s
# 897:	learn: 0.3518208	total: 1m 22s	remaining: 9.32s
# 898:	learn: 0.3518208	total: 1m 22s	remaining: 9.23s
# 899:	learn: 0.3518208	total: 1m 22s	remaining: 9.14s
# 900:	learn: 0.3518208	total: 1m 22s	remaining: 9.04s
# 901:	learn: 0.3518208	total: 1m 22s	remaining: 8.95s
# 902:	learn: 0.3518208	total: 1m 22s	remaining: 8.86s
# 903:	learn: 0.3518208	total: 1m 22s	remaining: 8.77s
# 904:	learn: 0.3518208	total: 1m 22s	remaining: 8.68s
# 905:	learn: 0.3518208	total: 1m 22s	remaining: 8.59s
# 906:	learn: 0.3518208	total: 1m 22s	remaining: 8.5s
# 907:	learn: 0.3518208	total: 1m 22s	remaining: 8.41s
# 908:	learn: 0.3518208	total: 1m 23s	remaining: 8.31s
# 909:	learn: 0.3518208	total: 1m 23s	remaining: 8.22s
# 910:	learn: 0.3518208	total: 1m 23s	remaining: 8.13s
# 911:	learn: 0.3518208	total: 1m 23s	remaining: 8.04s
# 912:	learn: 0.3518208	total: 1m 23s	remaining: 7.95s
# 913:	learn: 0.3518208	total: 1m 23s	remaining: 7.86s
# 914:	learn: 0.3518208	total: 1m 23s	remaining: 7.77s
# 915:	learn: 0.3518208	total: 1m 23s	remaining: 7.68s
# 916:	learn: 0.3518208	total: 1m 23s	remaining: 7.58s
# 917:	learn: 0.3518208	total: 1m 23s	remaining: 7.49s
# 918:	learn: 0.3518208	total: 1m 23s	remaining: 7.4s
# 919:	learn: 0.3518208	total: 1m 24s	remaining: 7.31s
# 920:	learn: 0.3518208	total: 1m 24s	remaining: 7.22s
# 921:	learn: 0.3518208	total: 1m 24s	remaining: 7.13s
# 922:	learn: 0.3518208	total: 1m 24s	remaining: 7.04s
# 923:	learn: 0.3518208	total: 1m 24s	remaining: 6.95s
# 924:	learn: 0.3518208	total: 1m 24s	remaining: 6.85s
# 925:	learn: 0.3518208	total: 1m 24s	remaining: 6.76s
# 926:	learn: 0.3518208	total: 1m 24s	remaining: 6.67s
# 927:	learn: 0.3518208	total: 1m 24s	remaining: 6.58s
# 928:	learn: 0.3518208	total: 1m 24s	remaining: 6.49s
# 929:	learn: 0.3518208	total: 1m 25s	remaining: 6.4s
# 930:	learn: 0.3518208	total: 1m 25s	remaining: 6.31s
# 931:	learn: 0.3518208	total: 1m 25s	remaining: 6.21s
# 932:	learn: 0.3518208	total: 1m 25s	remaining: 6.12s
# 933:	learn: 0.3518208	total: 1m 25s	remaining: 6.03s
# 934:	learn: 0.3518208	total: 1m 25s	remaining: 5.94s
# 935:	learn: 0.3518208	total: 1m 25s	remaining: 5.85s
# 936:	learn: 0.3518208	total: 1m 25s	remaining: 5.76s
# 937:	learn: 0.3518208	total: 1m 25s	remaining: 5.67s
# 938:	learn: 0.3518208	total: 1m 25s	remaining: 5.58s
# 939:	learn: 0.3518208	total: 1m 25s	remaining: 5.49s
# 940:	learn: 0.3518208	total: 1m 26s	remaining: 5.39s
# 941:	learn: 0.3518208	total: 1m 26s	remaining: 5.3s
# 942:	learn: 0.3518208	total: 1m 26s	remaining: 5.21s
# 943:	learn: 0.3518208	total: 1m 26s	remaining: 5.12s
# 944:	learn: 0.3518208	total: 1m 26s	remaining: 5.03s
# 945:	learn: 0.3518208	total: 1m 26s	remaining: 4.94s
# 946:	learn: 0.3518208	total: 1m 26s	remaining: 4.84s
# 947:	learn: 0.3518208	total: 1m 26s	remaining: 4.75s
# 948:	learn: 0.3518208	total: 1m 26s	remaining: 4.66s
# 949:	learn: 0.3518208	total: 1m 26s	remaining: 4.57s
# 950:	learn: 0.3518208	total: 1m 26s	remaining: 4.48s
# 951:	learn: 0.3518208	total: 1m 27s	remaining: 4.39s
# 952:	learn: 0.3518208	total: 1m 27s	remaining: 4.3s
# 953:	learn: 0.3518208	total: 1m 27s	remaining: 4.21s
# 954:	learn: 0.3518208	total: 1m 27s	remaining: 4.11s
# 955:	learn: 0.3518208	total: 1m 27s	remaining: 4.02s
# 956:	learn: 0.3518208	total: 1m 27s	remaining: 3.93s
# 957:	learn: 0.3518208	total: 1m 27s	remaining: 3.84s
# 958:	learn: 0.3518208	total: 1m 27s	remaining: 3.75s
# 959:	learn: 0.3518208	total: 1m 27s	remaining: 3.66s
# 960:	learn: 0.3518208	total: 1m 27s	remaining: 3.57s
# 961:	learn: 0.3518208	total: 1m 27s	remaining: 3.48s
# 962:	learn: 0.3518208	total: 1m 28s	remaining: 3.38s
# 963:	learn: 0.3518208	total: 1m 28s	remaining: 3.29s
# 964:	learn: 0.3518208	total: 1m 28s	remaining: 3.2s
# 965:	learn: 0.3518208	total: 1m 28s	remaining: 3.11s
# 966:	learn: 0.3518208	total: 1m 28s	remaining: 3.02s
# 967:	learn: 0.3518208	total: 1m 28s	remaining: 2.93s
# 968:	learn: 0.3518208	total: 1m 28s	remaining: 2.84s
# 969:	learn: 0.3518208	total: 1m 28s	remaining: 2.74s
# 970:	learn: 0.3518208	total: 1m 28s	remaining: 2.65s
# 971:	learn: 0.3518208	total: 1m 28s	remaining: 2.56s
# 972:	learn: 0.3518208	total: 1m 29s	remaining: 2.47s
# 973:	learn: 0.3518208	total: 1m 29s	remaining: 2.38s
# 974:	learn: 0.3518208	total: 1m 29s	remaining: 2.29s
# 975:	learn: 0.3518208	total: 1m 29s	remaining: 2.19s
# 976:	learn: 0.3518208	total: 1m 29s	remaining: 2.1s
# 977:	learn: 0.3518208	total: 1m 29s	remaining: 2.01s
# 978:	learn: 0.3518208	total: 1m 29s	remaining: 1.92s
# 979:	learn: 0.3518208	total: 1m 29s	remaining: 1.83s
# 980:	learn: 0.3518208	total: 1m 29s	remaining: 1.74s
# 981:	learn: 0.3518208	total: 1m 29s	remaining: 1.65s
# 982:	learn: 0.3518208	total: 1m 29s	remaining: 1.55s
# 983:	learn: 0.3518208	total: 1m 30s	remaining: 1.46s
# 984:	learn: 0.3518208	total: 1m 30s	remaining: 1.37s
# 985:	learn: 0.3518208	total: 1m 30s	remaining: 1.28s
# 986:	learn: 0.3518208	total: 1m 30s	remaining: 1.19s
# 987:	learn: 0.3518208	total: 1m 30s	remaining: 1.1s
# 988:	learn: 0.3518208	total: 1m 30s	remaining: 1.01s
# 989:	learn: 0.3518208	total: 1m 30s	remaining: 915ms
# 990:	learn: 0.3518208	total: 1m 30s	remaining: 823ms
# 991:	learn: 0.3518208	total: 1m 30s	remaining: 732ms
# 992:	learn: 0.3518208	total: 1m 30s	remaining: 640ms
# 993:	learn: 0.3518207	total: 1m 30s	remaining: 549ms
# 994:	learn: 0.3518207	total: 1m 31s	remaining: 457ms
# 995:	learn: 0.3518207	total: 1m 31s	remaining: 366ms
# 996:	learn: 0.3518207	total: 1m 31s	remaining: 274ms
# 997:	learn: 0.3518207	total: 1m 31s	remaining: 183ms
# 998:	learn: 0.3518207	total: 1m 31s	remaining: 91.5ms
# 999:	learn: 0.3518208	total: 1m 31s	remaining: 0us

# %%
X_train.columns
# Out:
# Index(['model', 'brand', 'bodyType', 'fuelType', 'gearbox', 'power',
#        'kilometer', 'notRepairedDamage', 'v_0', 'v_1',
#        ...
#        'new5*year', 'new6*year', 'new7*year', 'new8*year', 'new9*year',
#        'new10*year', 'new11*year', 'new12*year', 'new13*year', 'new14*year'],
#       dtype='object', length=139)

# %%
cat_reg.get_feature_importance()
# Out:
# array([5.54511440e+00, 5.29306869e-01, 3.07823693e-01, 1.50441225e+00,
#        0.00000000e+00, 7.27617135e-01, 9.07696946e-01, 0.00000000e+00,
#        7.86185043e-03, 1.83276701e-01, 1.77559468e+00, 7.21346330e-01,
#        9.28439928e-01, 3.92467851e-01, 1.51325441e+00, 8.24270740e-02,
#        4.19217348e-01, 9.20486111e-01, 2.07413736e+00, 2.90805401e+00,
#        1.29643136e+00, 1.81339867e-02, 3.15818599e+00, 9.40870665e-02,
#        3.41665666e+00, 7.18023555e-04, 1.58674106e-01, 1.39663782e-01,
#        2.65587713e-02, 2.53926617e-04, 1.57698759e-02, 6.80024691e-06,
#        4.90612118e-01, 7.54449894e-01, 5.91762554e-03, 1.40788897e-03,
#        9.38758624e-02, 3.98037808e-03, 2.98421857e-03, 3.45950582e-02,
#        2.34087627e-01, 7.78577959e-02, 3.81259007e-02, 7.88419711e-01,
#        5.47490609e-02, 1.36788638e-01, 3.45708508e-02, 9.58423866e-01,
#        0.00000000e+00, 0.00000000e+00, 3.72413336e-03, 0.00000000e+00,
#        1.80871998e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 2.92416970e-03, 5.42455002e-06, 1.69997485e-03,
#        0.00000000e+00, 2.44575088e-04, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 5.01119751e-03, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 4.07736147e-03, 0.00000000e+00,
#        1.13035409e+00, 7.55088082e-01, 1.40232322e+00, 5.85826847e-01,
#        2.49384114e-01, 2.41355882e+00, 3.81764765e-02, 9.84415305e-01,
#        1.60286944e-01, 1.17890967e+00, 1.85842938e-01, 4.95642107e-01,
#        1.70878771e-01, 3.92812675e-01, 6.19015863e-01, 2.97340799e+00,
#        1.12159171e+00, 9.42935449e-02, 3.48063440e-02, 2.74002445e-01,
#        1.02845607e-01, 1.05673005e+00, 2.51449867e-01, 6.73752470e-02,
#        6.26471842e+00, 4.65398452e+00, 1.93923584e-01, 2.06407687e+00,
#        5.00186281e-01, 1.30805613e+00, 8.90093459e-02, 7.90284757e-01,
#        0.00000000e+00, 9.02151423e-01, 8.54051015e-02, 2.49226229e-01,
#        2.34158942e-01, 0.00000000e+00, 0.00000000e+00, 1.31282004e+00,
#        2.33271030e-02, 3.48371536e-01, 0.00000000e+00, 3.40867747e-01,
#        1.18161784e+00, 3.08722723e-01, 1.95820823e+00, 0.00000000e+00,
#        2.39540825e+00, 3.42955013e-01, 4.64765075e-01, 4.10775542e+00,
#        9.12199923e-02, 4.92636068e-01, 3.53804131e-01, 3.62695728e+00,
#        1.35141559e+00, 9.09990556e+00, 1.05633238e+00, 2.66374746e-01,
#        4.69216582e-01, 2.88929800e-01, 7.33259936e-01])

# %%
lgb_instance.fit(X_train, Y_train)
